# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import norm
from ipywidgets import interact, widgets

# User input for initial values
D = float(input("Enter the annual quantity demanded (D): "))
H = float(input("Enter the holding cost per unit (H): "))
S = float(input("Enter the ordering cost (S): "))
Cb = float(input("Enter the backordering cost per unit per period (Cb): "))
Cs = float(input("Enter the stockout cost per unit per period (Cs): "))

def EOQ(S, D, H, Cb, Cs, lead_time=0, demand_variation=0, holding_cost_percentage=0.2):
    """
    Economic Order Quantity (EOQ) considering backordering costs and stockouts.

    Arguments:
    S: ordering cost
    D: annual demand
    H: holding cost per unit
    Cb: backordering cost per unit per period
    Cs: stockout cost per unit per period
    lead_time: lead time in periods
    demand_variation: standard deviation of demand variation

    Returns:
    {
        "Q": optimal order quantity,
        "number_of_orders": number of orders per year,
        "time_between_cycles": time between orders in months,
        "cycle_service_level": service level for order cycles,
        "ordering_cost": annual ordering cost,
        "holding_cost": annual holding cost,
        "backordering_cost": annual backordering cost,
        "stockout_cost": annual stockout cost,
        "total_cost": total cost per year,
    }
    """
    if S > 0 and D > 0 and H > 0 and Cb >= 0 and Cs >= 0:
        # Safety stock calculation based on service level
        z = 1.28  # Z-value for 80% service level (adjust as needed)
        safety_stock = z * demand_variation * np.sqrt(lead_time)

        # EOQ formula
        Q = np.sqrt((2 * S * D) / (H * (1 - (demand_variation**2) / (D**2))))

        # Number of orders and time between cycles
        number_of_orders = D / Q
        time_between_cycles = 12 / number_of_orders

        # Cycle service level and average inventory
        cycle_service_level = 1 - norm.cdf((safety_stock - lead_time * (D / 12)) / demand_variation)
        average_inventory = Q / 2 + safety_stock

        # Costs calculation
        ordering_cost = D / Q * S
        holding_cost = Q / 2 * H
        backordering_cost = max(0, lead_time * (D / 12 - Q) * Cb)
        stockout_cost = max(0, (Q - lead_time * (D / 12)) * Cs)
        total_cost = ordering_cost + holding_cost + backordering_cost + stockout_cost
        # Calculate lead time demand
        lead_time_demand = lead_time * D / 12

        result = {
            "Q": Q,
            "number_of_orders": number_of_orders,
            "time_between_cycles": time_between_cycles,
            "cycle_service_level": cycle_service_level,
            "average_inventory": average_inventory,  # Add this line
            "total_cost": total_cost,
            "lead_time_demand": lead_time_demand,  # Move this line here
        }

        print("EOQ Results:")
        for key, value in result.items():
            print(f"{key}: {value}")

        return result
# Generate random samples for demand and holding cost
np.random.seed(42)  # For reproducibility
demand_samples = np.random.normal(loc=D, scale=0.1*D, size=1000)
holding_cost_samples = np.random.normal(loc=H, scale=0.1*H, size=1000)

# Calculate EOQ for each scenario
eoq_results = []
for d, h in zip(demand_samples, holding_cost_samples):
    eoq_results.append(EOQ(S, d, h, Cb, Cs))
# Out:
# EOQ Results:
# Q: 166.20617885162562
# number_of_orders: 6.315477694954881
# time_between_cycles: 1.900093798064745
# cycle_service_level: nan
# average_inventory: 83.10308942581281
# total_cost: 1927.8845442567895
# lead_time_demand: 0.0
# EOQ Results:
# Q: 164.5636324708709
# number_of_orders: 5.992658007579179
# time_between_cycles: 2.0024503291899975
# cycle_service_level: nan
# average_inventory: 82.28181623543546
# total_cost: 1830.7101287679277
# lead_time_demand: 0.0
# EOQ Results:
# Q: 178.1957267306028
# number_of_orders: 5.9752771480305595
# time_between_cycles: 2.0082750477867255
# cycle_service_level: nan
# average_inventory: 89.0978633653014
# total_cost: 1828.2222897552886
# lead_time_demand: 0.0
# EOQ Results:
# Q: 192.2503043248012
# number_of_orders: 5.993764169517364
# time_between_cycles: 2.002080772718536
# cycle_service_level: nan
# average_inventory: 96.1251521624006
# total_cost: 1836.5793117201695
# lead_time_demand: 0.0
# EOQ Results:
# Q: 165.485424174241
# number_of_orders: 5.90133340988033
# time_between_cycles: 2.0334387445232216
# cycle_service_level: nan
# average_inventory: 82.7427120871205
# total_cost: 1803.4971077989471
# lead_time_demand: 0.0
# EOQ Results:
# Q: 167.89406228285054
# number_of_orders: 5.816681608786322
# time_between_cycles: 2.0630319496727374
# cycle_service_level: nan
# average_inventory: 83.94703114142527
# total_cost: 1778.5832950924664
# lead_time_demand: 0.0
# EOQ Results:
# Q: 178.55938318113454
# number_of_orders: 6.484796603358103
# time_between_cycles: 1.8504820943475528
# cycle_service_level: nan
# average_inventory: 89.27969159056727
# total_cost: 1981.1508576436577
# lead_time_demand: 0.0
# EOQ Results:
# Q: 174.27877406191465
# number_of_orders: 6.1782823451165925
# time_between_cycles: 1.9422874076781196
# cycle_service_level: nan
# average_inventory: 87.13938703095732
# total_cost: 1888.3404583473607
# lead_time_demand: 0.0
# EOQ Results:
# Q: 160.85949639411604
# number_of_orders: 5.924751617221685
# time_between_cycles: 2.0254013628384313
# cycle_service_level: nan
# average_inventory: 80.42974819705802
# total_cost: 1809.5973844453288
# lead_time_demand: 0.0
# EOQ Results:
# Q: 182.80107952171332
# number_of_orders: 5.767230735819428
# time_between_cycles: 2.080721328777389
# cycle_service_level: nan
# average_inventory: 91.40053976085666
# total_cost: 1766.7294366501712
# lead_time_demand: 0.0
# EOQ Results:
# Q: 158.99511787641958
# number_of_orders: 5.998034678398072
# time_between_cycles: 2.0006553218536753
# cycle_service_level: nan
# average_inventory: 79.49755893820979
# total_cost: 1831.209427094705
# lead_time_demand: 0.0
# EOQ Results:
# Q: 167.4770792200661
# number_of_orders: 5.692880656165279
# time_between_cycles: 2.1078959361293186
# cycle_service_level: nan
# average_inventory: 83.73853961003304
# total_cost: 1741.3596126935968
# lead_time_demand: 0.0
# EOQ Results:
# Q: 159.51589033036055
# number_of_orders: 6.420653296893952
# time_between_cycles: 1.8689686929218101
# cycle_service_level: nan
# average_inventory: 79.75794516518027
# total_cost: 1958.0991671342576
# lead_time_demand: 0.0
# EOQ Results:
# Q: 161.41840094699526
# number_of_orders: 5.009788046405953
# time_between_cycles: 2.395310917117314
# cycle_service_level: nan
# average_inventory: 80.70920047349763
# total_cost: 1535.220094111185
# lead_time_demand: 0.0
# EOQ Results:
# Q: 145.44118490640287
# number_of_orders: 5.689641605170027
# time_between_cycles: 2.1090959383269268
# cycle_service_level: nan
# average_inventory: 72.72059245320143
# total_cost: 1735.9807185322886
# lead_time_demand: 0.0
# EOQ Results:
# Q: 166.62432160987188
# number_of_orders: 5.6640665537748704
# time_between_cycles: 2.118619173357433
# cycle_service_level: nan
# average_inventory: 83.31216080493594
# total_cost: 1732.5448304544354
# lead_time_demand: 0.0
# EOQ Results:
# Q: 169.82405551079464
# number_of_orders: 5.292047026337984
# time_between_cycles: 2.267553545967602
# cycle_service_level: nan
# average_inventory: 84.91202775539732
# total_cost: 1621.5789190035541
# lead_time_demand: 0.0
# EOQ Results:
# Q: 180.32235734332934
# number_of_orders: 5.719893797171917
# time_between_cycles: 2.0979410502224973
# cycle_service_level: nan
# average_inventory: 90.16117867166467
# total_cost: 1752.032610620241
# lead_time_demand: 0.0
# EOQ Results:
# Q: 167.8648931595163
# number_of_orders: 5.416246216437283
# time_between_cycles: 2.2155565903895336
# cycle_service_level: nan
# average_inventory: 83.93244657975815
# total_cost: 1658.4468435630881
# lead_time_demand: 0.0
# EOQ Results:
# Q: 157.20932673645757
# number_of_orders: 5.462587034076511
# time_between_cycles: 2.196761337648634
# cycle_service_level: nan
# average_inventory: 78.60466336822878
# total_cost: 1670.2179755702448
# lead_time_demand: 0.0
# EOQ Results:
# Q: 180.79797164073236
# number_of_orders: 6.341691040486448
# time_between_cycles: 1.8922397706526435
# cycle_service_level: nan
# average_inventory: 90.39898582036618
# total_cost: 1938.6669064740806
# lead_time_demand: 0.0
# EOQ Results:
# Q: 176.37260763462928
# number_of_orders: 5.541803702172161
# time_between_cycles: 2.165359988354782
# cycle_service_level: nan
# average_inventory: 88.18630381731464
# total_cost: 1697.815632178574
# lead_time_demand: 0.0
# EOQ Results:
# Q: 174.00092344655218
# number_of_orders: 5.785905043073156
# time_between_cycles: 2.0740056932607827
# cycle_service_level: nan
# average_inventory: 87.00046172327609
# total_cost: 1770.5716976112574
# lead_time_demand: 0.0
# EOQ Results:
# Q: 145.55734289613875
# number_of_orders: 5.891322033753628
# time_between_cycles: 2.0368942541669646
# cycle_service_level: nan
# average_inventory: 72.77867144806937
# total_cost: 1796.5080787053162
# lead_time_demand: 0.0
# EOQ Results:
# Q: 155.5256588924835
# number_of_orders: 6.079779595733192
# time_between_cycles: 1.9737557605577736
# cycle_service_level: nan
# average_inventory: 77.76282944624175
# total_cost: 1855.0390104984544
# lead_time_demand: 0.0
# EOQ Results:
# Q: 170.48345972023
# number_of_orders: 5.930735219887186
# time_between_cycles: 2.023357906750095
# cycle_service_level: nan
# average_inventory: 85.241729860115
# total_cost: 1813.3172579102018
# lead_time_demand: 0.0
# EOQ Results:
# Q: 162.62383994537925
# number_of_orders: 5.441395570015952
# time_between_cycles: 2.2053166040940524
# cycle_service_level: nan
# average_inventory: 81.31191997268962
# total_cost: 1664.9434389938613
# lead_time_demand: 0.0
# EOQ Results:
# Q: 175.37931139740104
# number_of_orders: 5.9161470846665845
# time_between_cycles: 2.028347136787976
# cycle_service_level: nan
# average_inventory: 87.68965569870052
# total_cost: 1809.9199876794555
# lead_time_demand: 0.0
# EOQ Results:
# Q: 162.99719081516562
# number_of_orders: 5.7665787140711
# time_between_cycles: 2.080956594023186
# cycle_service_level: nan
# average_inventory: 81.49859540758281
# total_cost: 1762.5730523843629
# lead_time_demand: 0.0
# EOQ Results:
# Q: 180.1199140325376
# number_of_orders: 5.389912771362402
# time_between_cycles: 2.2263811139501564
# cycle_service_level: nan
# average_inventory: 90.0599570162688
# total_cost: 1652.997814215228
# lead_time_demand: 0.0
# EOQ Results:
# Q: 170.11678539580907
# number_of_orders: 5.524612615917756
# time_between_cycles: 2.1720979975003267
# cycle_service_level: nan
# average_inventory: 85.05839269790454
# total_cost: 1691.4071418544888
# lead_time_demand: 0.0
# EOQ Results:
# Q: 206.58659492257522
# number_of_orders: 5.737196156871141
# time_between_cycles: 2.0916140344318235
# cycle_service_level: nan
# average_inventory: 103.29329746128761
# total_cost: 1762.4761660458573
# lead_time_demand: 0.0
# EOQ Results:
# Q: 169.7332365709984
# number_of_orders: 5.883645994745862
# time_between_cycles: 2.0395516675741683
# cycle_service_level: nan
# average_inventory: 84.8666182854992
# total_cost: 1799.0404457379584
# lead_time_demand: 0.0
# EOQ Results:
# Q: 158.73304833261759
# number_of_orders: 5.633539559012283
# time_between_cycles: 2.1300995358775707
# cycle_service_level: nan
# average_inventory: 79.36652416630879
# total_cost: 1721.8084773702085
# lead_time_demand: 0.0
# EOQ Results:
# Q: 184.70538002859973
# number_of_orders: 5.859355537141057
# time_between_cycles: 2.0480068027848564
# cycle_service_level: nan
# average_inventory: 92.35269001429987
# total_cost: 1794.7477371480368
# lead_time_demand: 0.0
# EOQ Results:
# Q: 150.8500743144991
# number_of_orders: 5.819789211191101
# time_between_cycles: 2.0619303491138012
# cycle_service_level: nan
# average_inventory: 75.42503715724955
# total_cost: 1776.1067782202301
# lead_time_demand: 0.0
# EOQ Results:
# Q: 186.82918243810116
# number_of_orders: 5.4642767590052905
# time_between_cycles: 2.1960820304761546
# cycle_service_level: nan
# average_inventory: 93.41459121905058
# total_cost: 1676.6488641892074
# lead_time_demand: 0.0
# EOQ Results:
# Q: 168.1047149389429
# number_of_orders: 4.782929425293362
# time_between_cycles: 2.508922656592195
# cycle_service_level: nan
# average_inventory: 84.05235746947145
# total_cost: 1468.499770575797
# lead_time_demand: 0.0
# EOQ Results:
# Q: 159.51281778097479
# number_of_orders: 5.43643706614771
# time_between_cycles: 2.2073280448187487
# cycle_service_level: nan
# average_inventory: 79.75640889048739
# total_cost: 1662.833683400508
# lead_time_demand: 0.0
# EOQ Results:
# Q: 166.40630321826953
# number_of_orders: 6.1276892994216965
# time_between_cycles: 1.9583238336076383
# cycle_service_level: nan
# average_inventory: 83.20315160913476
# total_cost: 1871.588050470163
# lead_time_demand: 0.0
# EOQ Results:
# Q: 166.04940815927705
# number_of_orders: 6.4670309271412245
# time_between_cycles: 1.8555655810516813
# cycle_service_level: nan
# average_inventory: 83.02470407963852
# total_cost: 1973.319159774223
# lead_time_demand: 0.0
# EOQ Results:
# Q: 178.83426537696988
# number_of_orders: 5.687594745754932
# time_between_cycles: 2.10985496267231
# cycle_service_level: nan
# average_inventory: 89.41713268848494
# total_cost: 1742.0452768018736
# lead_time_demand: 0.0
# EOQ Results:
# Q: 163.60278682421816
# number_of_orders: 6.041676862284706
# time_between_cycles: 1.9862035447327961
# cycle_service_level: nan
# average_inventory: 81.80139341210908
# total_cost: 1845.2236160502555
# lead_time_demand: 0.0
# EOQ Results:
# Q: 170.90690141830612
# number_of_orders: 5.6749588366077806
# time_between_cycles: 2.114552782760452
# cycle_service_level: nan
# average_inventory: 85.45345070915306
# total_cost: 1736.6690312659953
# lead_time_demand: 0.0
# EOQ Results:
# Q: 161.28700512268026
# number_of_orders: 5.283425036723109
# time_between_cycles: 2.2712539529930855
# cycle_service_level: nan
# average_inventory: 80.64350256134013
# total_cost: 1617.284912041469
# lead_time_demand: 0.0
# EOQ Results:
# Q: 159.93767522569655
# number_of_orders: 5.802357561162228
# time_between_cycles: 2.06812487398594
# cycle_service_level: nan
# average_inventory: 79.96883761284828
# total_cost: 1772.6948033938077
# lead_time_demand: 0.0
# EOQ Results:
# Q: 163.90723111754374
# number_of_orders: 5.819975826569356
# time_between_cycles: 2.061864234077673
# cycle_service_level: nan
# average_inventory: 81.95361555877187
# total_cost: 1778.774194194316
# lead_time_demand: 0.0
# EOQ Results:
# Q: 198.44155082179046
# number_of_orders: 5.5719793462754765
# time_between_cycles: 2.1536332520724897
# cycle_service_level: nan
# average_inventory: 99.22077541089523
# total_cost: 1711.2821140470012
# lead_time_demand: 0.0
# EOQ Results:
# Q: 164.4339070796043
# number_of_orders: 6.290441231540525
# time_between_cycles: 1.907656324620206
# cycle_service_level: nan
# average_inventory: 82.21695353980215
# total_cost: 1920.0191508780783
# lead_time_demand: 0.0
# EOQ Results:
# Q: 147.35715482326805
# number_of_orders: 5.589792945253467
# time_between_cycles: 2.146770035585972
# cycle_service_level: nan
# average_inventory: 73.67857741163402
# total_cost: 1706.4093145406937
# lead_time_demand: 0.0
# EOQ Results:
# Q: 181.76647588409034
# number_of_orders: 5.679861437143284
# time_between_cycles: 2.1127275960512626
# cycle_service_level: nan
# average_inventory: 90.88323794204517
# total_cost: 1740.3117263198035
# lead_time_demand: 0.0
# EOQ Results:
# Q: 166.57291340543105
# number_of_orders: 5.772197605850479
# time_between_cycles: 2.078930906287279
# cycle_service_level: nan
# average_inventory: 83.28645670271553
# total_cost: 1764.9738644362299
# lead_time_demand: 0.0
# EOQ Results:
# Q: 163.25599254368598
# number_of_orders: 5.710711046149967
# time_between_cycles: 2.1013145128556503
# cycle_service_level: nan
# average_inventory: 81.62799627184299
# total_cost: 1745.8645123537276
# lead_time_demand: 0.0
# EOQ Results:
# Q: 176.14271422155798
# number_of_orders: 6.024476422847192
# time_between_cycles: 1.9918743402316696
# cycle_service_level: nan
# average_inventory: 88.07135711077899
# total_cost: 1842.5714696984692
# lead_time_demand: 0.0
# EOQ Results:
# Q: 187.1367867473725
# number_of_orders: 5.894618430841916
# time_between_cycles: 2.0357551792009825
# cycle_service_level: nan
# average_inventory: 93.56839337368625
# total_cost: 1805.8128866020493
# lead_time_demand: 0.0
# EOQ Results:
# Q: 187.496473123113
# number_of_orders: 5.830125728252262
# time_between_cycles: 2.0582746512393526
# cycle_service_level: nan
# average_inventory: 93.7482365615565
# total_cost: 1786.537013100301
# lead_time_demand: 0.0
# EOQ Results:
# Q: 165.99022844269544
# number_of_orders: 5.518868527818145
# time_between_cycles: 2.1743587366709995
# cycle_service_level: nan
# average_inventory: 82.99511422134772
# total_cost: 1688.8586040339828
# lead_time_demand: 0.0
# EOQ Results:
# Q: 161.30971821842394
# number_of_orders: 6.007565899425119
# time_between_cycles: 1.997481209677336
# cycle_service_level: nan
# average_inventory: 80.65485910921197
# total_cost: 1834.5317134712207
# lead_time_demand: 0.0
# EOQ Results:
# Q: 171.45212856944383
# number_of_orders: 6.025742297634443
# time_between_cycles: 1.9914558916186813
# cycle_service_level: nan
# average_inventory: 85.72606428472191
# total_cost: 1842.0131150042214
# lead_time_demand: 0.0
# EOQ Results:
# Q: 184.91595582762557
# number_of_orders: 5.935423516050455
# time_between_cycles: 2.0217596886809908
# cycle_service_level: nan
# average_inventory: 92.45797791381278
# total_cost: 1817.6102459806616
# lead_time_demand: 0.0
# EOQ Results:
# Q: 162.8380290988669
# number_of_orders: 5.846807293629274
# time_between_cycles: 2.0524021739309406
# cycle_service_level: nan
# average_inventory: 81.41901454943346
# total_cost: 1786.6097939085557
# lead_time_demand: 0.0
# EOQ Results:
# Q: 202.90554812124236
# number_of_orders: 4.83690126475586
# time_between_cycles: 2.4809272183077513
# cycle_service_level: nan
# average_inventory: 101.45277406062118
# total_cost: 1491.6514890510066
# lead_time_demand: 0.0
# EOQ Results:
# Q: 154.69903944637136
# number_of_orders: 5.749011149534053
# time_between_cycles: 2.08731548572011
# cycle_service_level: nan
# average_inventory: 77.34951972318568
# total_cost: 1755.6431527494901
# lead_time_demand: 0.0
# EOQ Results:
# Q: 178.81255137811078
# number_of_orders: 4.923476181100472
# time_between_cycles: 2.4373023365206605
# cycle_service_level: nan
# average_inventory: 89.40627568905539
# total_cost: 1512.8053646057638
# lead_time_demand: 0.0
# EOQ Results:
# Q: 183.4597004159702
# number_of_orders: 5.893678992104669
# time_between_cycles: 2.036079673846425
# cycle_service_level: nan
# average_inventory: 91.7298502079851
# total_cost: 1804.795637714595
# lead_time_demand: 0.0
# EOQ Results:
# Q: 195.867939230714
# number_of_orders: 5.7979065247601556
# time_between_cycles: 2.0697125675885935
# cycle_service_level: nan
# average_inventory: 97.933969615357
# total_cost: 1778.5455452741894
# lead_time_demand: 0.0
# EOQ Results:
# Q: 184.96900356996022
# number_of_orders: 5.367380310650068
# time_between_cycles: 2.235727544066395
# cycle_service_level: nan
# average_inventory: 92.48450178498011
# total_cost: 1647.2078939090127
# lead_time_demand: 0.0
# EOQ Results:
# Q: 171.98022644177618
# number_of_orders: 6.398138393902664
# time_between_cycles: 1.8755455510990247
# cycle_service_level: nan
# average_inventory: 85.99011322088809
# total_cost: 1953.8375634591544
# lead_time_demand: 0.0
# EOQ Results:
# Q: 180.5826284581674
# number_of_orders: 5.7378919077191
# time_between_cycles: 2.091360414764276
# cycle_service_level: nan
# average_inventory: 90.2913142290837
# total_cost: 1757.4840980073636
# lead_time_demand: 0.0
# EOQ Results:
# Q: 164.69595430491768
# number_of_orders: 5.68009110173725
# time_between_cycles: 2.1126421715894335
# cycle_service_level: nan
# average_inventory: 82.34797715245884
# total_cost: 1736.9665213821586
# lead_time_demand: 0.0
# EOQ Results:
# Q: 176.7221637983077
# number_of_orders: 5.863099105856261
# time_between_cycles: 2.0466991574496833
# cycle_service_level: nan
# average_inventory: 88.36108189915385
# total_cost: 1794.2741645165397
# lead_time_demand: 0.0
# EOQ Results:
# Q: 181.76374605974112
# number_of_orders: 6.347820627923078
# time_between_cycles: 1.890412584630048
# cycle_service_level: nan
# average_inventory: 90.88187302987056
# total_cost: 1940.6989375888718
# lead_time_demand: 0.0
# EOQ Results:
# Q: 172.234237495165
# number_of_orders: 5.785245782604498
# time_between_cycles: 2.074242037578158
# cycle_service_level: nan
# average_inventory: 86.1171187475825
# total_cost: 1770.0205822803828
# lead_time_demand: 0.0
# EOQ Results:
# Q: 199.50006352492136
# number_of_orders: 5.796812016738713
# time_between_cycles: 2.070103354283205
# cycle_service_level: nan
# average_inventory: 99.75003176246068
# total_cost: 1778.943617726598
# lead_time_demand: 0.0
# EOQ Results:
# Q: 141.89715024550884
# number_of_orders: 5.201129750062649
# time_between_cycles: 2.307191048224755
# cycle_service_level: nan
# average_inventory: 70.94857512275442
# total_cost: 1588.7183550678965
# lead_time_demand: 0.0
# EOQ Results:
# Q: 184.8025546809989
# number_of_orders: 5.855926896170724
# time_between_cycles: 2.0492059092894372
# cycle_service_level: nan
# average_inventory: 92.40127734049945
# total_cost: 1793.738579787417
# lead_time_demand: 0.0
# EOQ Results:
# Q: 189.31433638049322
# number_of_orders: 5.328200315460911
# time_between_cycles: 2.2521675780806207
# cycle_service_level: nan
# average_inventory: 94.65716819024661
# total_cost: 1636.322961914372
# lead_time_demand: 0.0
# EOQ Results:
# Q: 174.36928336807532
# number_of_orders: 5.563475666213729
# time_between_cycles: 2.156925044693635
# cycle_service_level: nan
# average_inventory: 87.18464168403766
# total_cost: 1703.9165565377339
# lead_time_demand: 0.0
# EOQ Results:
# Q: 162.24855385345438
# number_of_orders: 6.219938814154578
# time_between_cycles: 1.9292794283911383
# cycle_service_level: nan
# average_inventory: 81.12427692672719
# total_cost: 1898.4313550170643
# lead_time_demand: 0.0
# EOQ Results:
# Q: 148.84130668491358
# number_of_orders: 5.3832039397241065
# time_between_cycles: 2.2291557470912036
# cycle_service_level: nan
# average_inventory: 74.42065334245679
# total_cost: 1644.7294432542146
# lead_time_demand: 0.0
# EOQ Results:
# Q: 174.35859273745498
# number_of_orders: 5.609318106214285
# time_between_cycles: 2.139297464108123
# cycle_service_level: nan
# average_inventory: 87.17929636872749
# total_cost: 1717.6671504117764
# lead_time_demand: 0.0
# EOQ Results:
# Q: 179.43188363385812
# number_of_orders: 5.772169561930295
# time_between_cycles: 2.0789410067134324
# cycle_service_level: nan
# average_inventory: 89.71594181692906
# total_cost: 1767.53724530586
# lead_time_demand: 0.0
# EOQ Results:
# Q: 188.62130092834113
# number_of_orders: 6.085152624995449
# time_between_cycles: 1.97201298628216
# cycle_service_level: nan
# average_inventory: 94.31065046417056
# total_cost: 1863.270047684303
# lead_time_demand: 0.0
# EOQ Results:
# Q: 153.47209186513686
# number_of_orders: 6.178145919883853
# time_between_cycles: 1.9423302970845977
# cycle_service_level: nan
# average_inventory: 76.73604593256843
# total_cost: 1884.1381943381834
# lead_time_demand: 0.0
# EOQ Results:
# Q: 162.972681765197
# number_of_orders: 5.639906208544498
# time_between_cycles: 2.1276949573771127
# cycle_service_level: nan
# average_inventory: 81.4863408825985
# total_cost: 1724.5663989163888
# lead_time_demand: 0.0
# EOQ Results:
# Q: 165.28720780492725
# number_of_orders: 5.746508203844386
# time_between_cycles: 2.0882246356095093
# cycle_service_level: nan
# average_inventory: 82.64360390246362
# total_cost: 1757.0099027143015
# lead_time_demand: 0.0
# EOQ Results:
# Q: 172.30074712344228
# number_of_orders: 6.335086933710101
# time_between_cycles: 1.8942123644974642
# cycle_service_level: nan
# average_inventory: 86.15037356172114
# total_cost: 1934.9862295377186
# lead_time_demand: 0.0
# EOQ Results:
# Q: 173.96433994053
# number_of_orders: 5.937280659467673
# time_between_cycles: 2.021127295180939
# cycle_service_level: nan
# average_inventory: 86.982169970265
# total_cost: 1815.9770658284078
# lead_time_demand: 0.0
# EOQ Results:
# Q: 170.7812874381929
# number_of_orders: 5.545244410726389
# time_between_cycles: 2.164016427623626
# cycle_service_level: nan
# average_inventory: 85.39064371909645
# total_cost: 1697.7295807055555
# lead_time_demand: 0.0
# EOQ Results:
# Q: 179.36412406149051
# number_of_orders: 5.861410406413907
# time_between_cycles: 2.047288820941267
# cycle_service_level: nan
# average_inventory: 89.68206203074526
# total_cost: 1794.2959467364703
# lead_time_demand: 0.0
# EOQ Results:
# Q: 174.67022024689595
# number_of_orders: 5.7806519823904985
# time_between_cycles: 2.075890407614123
# cycle_service_level: nan
# average_inventory: 87.33511012344798
# total_cost: 1769.1296387665288
# lead_time_demand: 0.0
# EOQ Results:
# Q: 181.73848198550266
# number_of_orders: 6.035400356985408
# time_between_cycles: 1.9882690940479413
# cycle_service_level: nan
# average_inventory: 90.86924099275133
# total_cost: 1846.967803492723
# lead_time_demand: 0.0
# EOQ Results:
# Q: 161.25094723696276
# number_of_orders: 5.766134751728965
# time_between_cycles: 2.081116816841962
# cycle_service_level: nan
# average_inventory: 80.62547361848138
# total_cost: 1762.0906149660823
# lead_time_demand: 0.0
# EOQ Results:
# Q: 169.903093128094
# number_of_orders: 5.692855659849597
# time_between_cycles: 2.1079051915250977
# cycle_service_level: nan
# average_inventory: 84.951546564047
# total_cost: 1741.8373165804978
# lead_time_demand: 0.0
# EOQ Results:
# Q: 163.87828014688827
# number_of_orders: 5.862821990965517
# time_between_cycles: 2.0467958976908633
# cycle_service_level: nan
# average_inventory: 81.93914007344414
# total_cost: 1791.6222533190328
# lead_time_demand: 0.0
# EOQ Results:
# Q: 160.67933281911897
# number_of_orders: 5.312746139839671
# time_between_cycles: 2.2587188779854137
# cycle_service_level: nan
# average_inventory: 80.33966640955948
# total_cost: 1625.9597085157254
# lead_time_demand: 0.0
# EOQ Results:
# Q: 175.06388746866355
# number_of_orders: 5.881350189317361
# time_between_cycles: 2.04034781363577
# cycle_service_level: nan
# average_inventory: 87.53194373433178
# total_cost: 1799.4178342889413
# lead_time_demand: 0.0
# EOQ Results:
# Q: 196.1384835871764
# number_of_orders: 5.2315359456825945
# time_between_cycles: 2.2937814295060295
# cycle_service_level: nan
# average_inventory: 98.0692417935882
# total_cost: 1608.6884804222136
# lead_time_demand: 0.0
# EOQ Results:
# Q: 165.81864218863836
# number_of_orders: 6.033768775684737
# time_between_cycles: 1.988806738560874
# cycle_service_level: nan
# average_inventory: 82.90932109431918
# total_cost: 1843.294361143149
# lead_time_demand: 0.0
# EOQ Results:
# Q: 168.271064773701
# number_of_orders: 5.803382108360608
# time_between_cycles: 2.0677597607629994
# cycle_service_level: nan
# average_inventory: 84.1355323868505
# total_cost: 1774.6688454629223
# lead_time_demand: 0.0
# EOQ Results:
# Q: 153.02568849111643
# number_of_orders: 5.609926896978442
# time_between_cycles: 2.139065306976337
# cycle_service_level: nan
# average_inventory: 76.51284424555821
# total_cost: 1713.5832067917559
# lead_time_demand: 0.0
# EOQ Results:
# Q: 201.13381165411056
# number_of_orders: 4.762677442670971
# time_between_cycles: 2.5195911636775143
# cycle_service_level: nan
# average_inventory: 100.56690582705528
# total_cost: 1469.0299951321135
# lead_time_demand: 0.0
# EOQ Results:
# Q: 154.81185183696684
# number_of_orders: 6.238078912487506
# time_between_cycles: 1.9236691565376274
# cycle_service_level: nan
# average_inventory: 77.40592591848342
# total_cost: 1902.386044113645
# lead_time_demand: 0.0
# EOQ Results:
# Q: 167.28357037408696
# number_of_orders: 5.498282174519605
# time_between_cycles: 2.182499846153942
# cycle_service_level: nan
# average_inventory: 83.64178518704348
# total_cost: 1682.9413664306987
# lead_time_demand: 0.0
# EOQ Results:
# Q: 163.0077648838721
# number_of_orders: 6.035733509592725
# time_between_cycles: 1.9881593481435411
# cycle_service_level: nan
# average_inventory: 81.50388244193606
# total_cost: 1843.321605854592
# lead_time_demand: 0.0
# EOQ Results:
# Q: 186.64036533454995
# number_of_orders: 5.574384103977422
# time_between_cycles: 2.1527041868962327
# cycle_service_level: nan
# average_inventory: 93.32018266727498
# total_cost: 1709.6433042601366
# lead_time_demand: 0.0
# EOQ Results:
# Q: 183.30209578694692
# number_of_orders: 6.484478996369967
# time_between_cycles: 1.8505727301634627
# cycle_service_level: nan
# average_inventory: 91.65104789347346
# total_cost: 1982.0041180683795
# lead_time_demand: 0.0
# EOQ Results:
# Q: 184.7099086660007
# number_of_orders: 5.50840931399619
# time_between_cycles: 2.1784873483365654
# cycle_service_level: nan
# average_inventory: 92.35495433300035
# total_cost: 1689.4647759320576
# lead_time_demand: 0.0
# EOQ Results:
# Q: 181.16250066555452
# number_of_orders: 5.662071539661129
# time_between_cycles: 2.119365662539508
# cycle_service_level: nan
# average_inventory: 90.58125033277726
# total_cost: 1734.85396203145
# lead_time_demand: 0.0
# EOQ Results:
# Q: 158.09154294097138
# number_of_orders: 6.2783586645997005
# time_between_cycles: 1.911327568407579
# cycle_service_level: nan
# average_inventory: 79.04577147048569
# total_cost: 1915.1259079681042
# lead_time_demand: 0.0
# EOQ Results:
# Q: 157.20991409373354
# number_of_orders: 5.140406590313811
# time_between_cycles: 2.33444568813134
# cycle_service_level: nan
# average_inventory: 78.60495704686677
# total_cost: 1573.5639599128897
# lead_time_demand: 0.0
# EOQ Results:
# Q: 171.12490682907648
# number_of_orders: 5.828190828184077
# time_between_cycles: 2.058957977485941
# cycle_service_level: nan
# average_inventory: 85.56245341453824
# total_cost: 1782.6822298210384
# lead_time_demand: 0.0
# EOQ Results:
# Q: 166.6281842058844
# number_of_orders: 6.037532160532153
# time_between_cycles: 1.9875670523868996
# cycle_service_level: nan
# average_inventory: 83.3140921029422
# total_cost: 1844.5852850008225
# lead_time_demand: 0.0
# EOQ Results:
# Q: 188.74298256870543
# number_of_orders: 6.603287678760967
# time_between_cycles: 1.8172765724863384
# cycle_service_level: nan
# average_inventory: 94.37149128435271
# total_cost: 2018.7349001420316
# lead_time_demand: 0.0
# EOQ Results:
# Q: 170.25539445034346
# number_of_orders: 5.7605452484381425
# time_between_cycles: 2.0831361411931555
# cycle_service_level: nan
# average_inventory: 85.12769722517173
# total_cost: 1762.2146534215117
# lead_time_demand: 0.0
# EOQ Results:
# Q: 172.6744265992554
# number_of_orders: 5.96587899274833
# time_between_cycles: 2.01143871918728
# cycle_service_level: nan
# average_inventory: 86.3372132996277
# total_cost: 1824.2985831443502
# lead_time_demand: 0.0
# EOQ Results:
# Q: 155.25118079128202
# number_of_orders: 6.418816384844106
# time_between_cycles: 1.869503547154581
# cycle_service_level: nan
# average_inventory: 77.62559039564101
# total_cost: 1956.6951516114887
# lead_time_demand: 0.0
# EOQ Results:
# Q: 163.24063712462714
# number_of_orders: 5.410002140360514
# time_between_cycles: 2.2181137250345597
# cycle_service_level: nan
# average_inventory: 81.62031856231357
# total_cost: 1655.6487695330798
# lead_time_demand: 0.0
# EOQ Results:
# Q: 181.02341665472935
# number_of_orders: 6.155459343565488
# time_between_cycles: 1.9494889544748615
# cycle_service_level: nan
# average_inventory: 90.51170832736467
# total_cost: 1882.842486400592
# lead_time_demand: 0.0
# EOQ Results:
# Q: 170.84800203676377
# number_of_orders: 6.29327408252227
# time_between_cycles: 1.9067976132370419
# cycle_service_level: nan
# average_inventory: 85.42400101838189
# total_cost: 1922.1518251640339
# lead_time_demand: 0.0
# EOQ Results:
# Q: 170.73499697680083
# number_of_orders: 6.320339788631217
# time_between_cycles: 1.898632099113585
# cycle_service_level: nan
# average_inventory: 85.36749848840041
# total_cost: 1930.248935984725
# lead_time_demand: 0.0
# EOQ Results:
# Q: 156.13482974614533
# number_of_orders: 5.822283573745461
# time_between_cycles: 2.061046984058255
# cycle_service_level: nan
# average_inventory: 78.06741487307266
# total_cost: 1777.912038072867
# lead_time_demand: 0.0
# EOQ Results:
# Q: 179.31696285345654
# number_of_orders: 6.359015973438509
# time_between_cycles: 1.8870844247166192
# cycle_service_level: nan
# average_inventory: 89.65848142672827
# total_cost: 1943.568184602244
# lead_time_demand: 0.0
# EOQ Results:
# Q: 170.65534979207905
# number_of_orders: 5.038311982415685
# time_between_cycles: 2.3817500865133887
# cycle_service_level: nan
# average_inventory: 85.32767489603953
# total_cost: 1545.6246646831212
# lead_time_demand: 0.0
# EOQ Results:
# Q: 165.23050631841357
# number_of_orders: 6.4073259410090255
# time_between_cycles: 1.8728561822016878
# cycle_service_level: nan
# average_inventory: 82.61525315920679
# total_cost: 1955.2438835663904
# lead_time_demand: 0.0
# EOQ Results:
# Q: 203.2400572407049
# number_of_orders: 5.998057563707708
# time_between_cycles: 2.0006476884463544
# cycle_service_level: nan
# average_inventory: 101.62002862035246
# total_cost: 1840.0652805604536
# lead_time_demand: 0.0
# EOQ Results:
# Q: 161.97050261285256
# number_of_orders: 5.562410148472553
# time_between_cycles: 2.1573382184510828
# cycle_service_level: nan
# average_inventory: 80.98525130642628
# total_cost: 1701.117145064337
# lead_time_demand: 0.0
# EOQ Results:
# Q: 174.95696818500502
# number_of_orders: 5.3920128865183194
# time_between_cycles: 2.2255139690047234
# cycle_service_level: nan
# average_inventory: 87.47848409250251
# total_cost: 1652.5952595924969
# lead_time_demand: 0.0
# EOQ Results:
# Q: 174.62686230789782
# number_of_orders: 5.7835611495327575
# time_between_cycles: 2.074846221859253
# cycle_service_level: nan
# average_inventory: 87.31343115394891
# total_cost: 1769.993717321407
# lead_time_demand: 0.0
# EOQ Results:
# Q: 166.08056994291638
# number_of_orders: 5.7180224930272425
# time_between_cycles: 2.0986276312542005
# cycle_service_level: nan
# average_inventory: 83.04028497145819
# total_cost: 1748.622861896756
# lead_time_demand: 0.0
# EOQ Results:
# Q: 156.71245995708264
# number_of_orders: 5.3916175977633225
# time_between_cycles: 2.2256771335152035
# cycle_service_level: nan
# average_inventory: 78.35622997854132
# total_cost: 1648.8277713204136
# lead_time_demand: 0.0
# EOQ Results:
# Q: 170.24348046751035
# number_of_orders: 5.914213541191984
# time_between_cycles: 2.029010267624096
# cycle_service_level: nan
# average_inventory: 85.12174023375518
# total_cost: 1808.3127584510974
# lead_time_demand: 0.0
# EOQ Results:
# Q: 151.94552405590426
# number_of_orders: 5.882171483370257
# time_between_cycles: 2.040062931508495
# cycle_service_level: nan
# average_inventory: 75.97276202795213
# total_cost: 1795.040549822258
# lead_time_demand: 0.0
# EOQ Results:
# Q: 173.37117314349754
# number_of_orders: 6.0411383511642365
# time_between_cycles: 1.9863805962476233
# cycle_service_level: nan
# average_inventory: 86.68558657174877
# total_cost: 1847.0157399779703
# lead_time_demand: 0.0
# EOQ Results:
# Q: 167.10325559290402
# number_of_orders: 5.434110624324545
# time_between_cycles: 2.2082730421947545
# cycle_service_level: nan
# average_inventory: 83.55162779645201
# total_cost: 1663.6538384159444
# lead_time_demand: 0.0
# EOQ Results:
# Q: 177.77232255259747
# number_of_orders: 6.497037468585843
# time_between_cycles: 1.8469956588709564
# cycle_service_level: nan
# average_inventory: 88.88616127629874
# total_cost: 1984.6657050862723
# lead_time_demand: 0.0
# EOQ Results:
# Q: 157.19715652238492
# number_of_orders: 5.863176479500312
# time_between_cycles: 2.0466721481019956
# cycle_service_level: nan
# average_inventory: 78.59857826119246
# total_cost: 1790.3923751545706
# lead_time_demand: 0.0
# EOQ Results:
# Q: 181.92527343009291
# number_of_orders: 5.31973282289071
# time_between_cycles: 2.255752384473939
# cycle_service_level: nan
# average_inventory: 90.96263671504646
# total_cost: 1632.3049015532315
# lead_time_demand: 0.0
# EOQ Results:
# Q: 174.96228840810485
# number_of_orders: 6.18048455799047
# time_between_cycles: 1.9415953372920802
# cycle_service_level: nan
# average_inventory: 87.48114420405243
# total_cost: 1889.137825078762
# lead_time_demand: 0.0
# EOQ Results:
# Q: 156.79179604949763
# number_of_orders: 5.5928536470095125
# time_between_cycles: 2.145595210848468
# cycle_service_level: nan
# average_inventory: 78.39589802474882
# total_cost: 1709.2144533127534
# lead_time_demand: 0.0
# EOQ Results:
# Q: 177.82962649873915
# number_of_orders: 5.751268861084092
# time_between_cycles: 2.0864960915317123
# cycle_service_level: nan
# average_inventory: 88.91481324936957
# total_cost: 1760.9465836249753
# lead_time_demand: 0.0
# EOQ Results:
# Q: 172.68231799451303
# number_of_orders: 6.547944737828753
# time_between_cycles: 1.8326361141494767
# cycle_service_level: nan
# average_inventory: 86.34115899725651
# total_cost: 1998.9198849475283
# lead_time_demand: 0.0
# EOQ Results:
# Q: 159.8784194887143
# number_of_orders: 5.249311815989771
# time_between_cycles: 2.2860139425223625
# cycle_service_level: nan
# average_inventory: 79.93920974435714
# total_cost: 1606.769228694674
# lead_time_demand: 0.0
# EOQ Results:
# Q: 173.7094555339952
# number_of_orders: 5.8630279090012785
# time_between_cycles: 2.046724011253105
# cycle_service_level: nan
# average_inventory: 86.8547277669976
# total_cost: 1793.6502638071827
# lead_time_demand: 0.0
# EOQ Results:
# Q: 176.9794887585254
# number_of_orders: 5.797215748683299
# time_between_cycles: 2.0699591873435996
# cycle_service_level: nan
# average_inventory: 88.4897443792627
# total_cost: 1774.5606223566947
# lead_time_demand: 0.0
# EOQ Results:
# Q: 179.70853023266932
# number_of_orders: 5.999616633566611
# time_between_cycles: 2.0001277969766416
# cycle_service_level: nan
# average_inventory: 89.85426511633466
# total_cost: 1835.8266961165173
# lead_time_demand: 0.0
# EOQ Results:
# Q: 171.83134429401014
# number_of_orders: 5.099796736809553
# time_between_cycles: 2.3530349579201526
# cycle_service_level: nan
# average_inventory: 85.91567214700507
# total_cost: 1564.305289901668
# lead_time_demand: 0.0
# EOQ Results:
# Q: 174.4108405073585
# number_of_orders: 4.976493067556502
# time_between_cycles: 2.4113366254305055
# cycle_service_level: nan
# average_inventory: 87.20542025367925
# total_cost: 1527.8300883684226
# lead_time_demand: 0.0
# EOQ Results:
# Q: 164.99943719905727
# number_of_orders: 6.3769560334458015
# time_between_cycles: 1.8817755582855689
# cycle_service_level: nan
# average_inventory: 82.49971859952863
# total_cost: 1946.0866974735516
# lead_time_demand: 0.0
# EOQ Results:
# Q: 183.7100910255964
# number_of_orders: 5.605018546204141
# time_between_cycles: 2.1409385002172208
# cycle_service_level: nan
# average_inventory: 91.8550455127982
# total_cost: 1718.2475820663617
# lead_time_demand: 0.0
# EOQ Results:
# Q: 184.75838807033207
# number_of_orders: 5.548052760908379
# time_between_cycles: 2.1629210314206255
# cycle_service_level: nan
# average_inventory: 92.37919403516604
# total_cost: 1701.3675058865804
# lead_time_demand: 0.0
# EOQ Results:
# Q: 198.89105016538974
# number_of_orders: 5.202068268478289
# time_between_cycles: 2.306774801998176
# cycle_service_level: nan
# average_inventory: 99.44552508269487
# total_cost: 1600.3986905765648
# lead_time_demand: 0.0
# EOQ Results:
# Q: 172.82477398097322
# number_of_orders: 5.392731067276022
# time_between_cycles: 2.2252175846145885
# cycle_service_level: nan
# average_inventory: 86.41238699048661
# total_cost: 1652.384274979001
# lead_time_demand: 0.0
# EOQ Results:
# Q: 188.08914206831457
# number_of_orders: 5.440108655205954
# time_between_cycles: 2.20583829488709
# cycle_service_level: nan
# average_inventory: 94.04457103415729
# total_cost: 1669.6504249754491
# lead_time_demand: 0.0
# EOQ Results:
# Q: 162.861736998419
# number_of_orders: 6.320129370472454
# time_between_cycles: 1.8986953109004086
# cycle_service_level: nan
# average_inventory: 81.4308684992095
# total_cost: 1928.6111585414199
# lead_time_demand: 0.0
# EOQ Results:
# Q: 159.06575721378874
# number_of_orders: 5.837616307005327
# time_between_cycles: 2.0556335615274364
# cycle_service_level: nan
# average_inventory: 79.53287860689437
# total_cost: 1783.0980435443557
# lead_time_demand: 0.0
# EOQ Results:
# Q: 195.51977787504057
# number_of_orders: 6.068835920388749
# time_between_cycles: 1.9773149509092875
# cycle_service_level: nan
# average_inventory: 97.75988893752029
# total_cost: 1859.754731691633
# lead_time_demand: 0.0
# EOQ Results:
# Q: 160.14088724327928
# number_of_orders: 6.540386469197202
# time_between_cycles: 1.834753963930963
# cycle_service_level: nan
# average_inventory: 80.07044362163964
# total_cost: 1994.1441182078167
# lead_time_demand: 0.0
# EOQ Results:
# Q: 155.12449054905733
# number_of_orders: 5.678469254995972
# time_between_cycles: 2.1132455704400064
# cycle_service_level: nan
# average_inventory: 77.56224527452866
# total_cost: 1734.5656746086029
# lead_time_demand: 0.0
# EOQ Results:
# Q: 181.77733963723418
# number_of_orders: 5.862421372158209
# time_between_cycles: 2.0469357690647008
# cycle_service_level: nan
# average_inventory: 90.88866981861709
# total_cost: 1795.0818795749094
# lead_time_demand: 0.0
# EOQ Results:
# Q: 189.99582351314115
# number_of_orders: 4.750271960135186
# time_between_cycles: 2.5261711541371406
# cycle_service_level: nan
# average_inventory: 94.99791175657057
# total_cost: 1463.080752743184
# lead_time_demand: 0.0
# EOQ Results:
# Q: 162.2632144256048
# number_of_orders: 6.647892833830287
# time_between_cycles: 1.80508324967778
# cycle_service_level: nan
# average_inventory: 81.1316072128024
# total_cost: 2026.820493034207
# lead_time_demand: 0.0
# EOQ Results:
# Q: 197.17553969832323
# number_of_orders: 5.659218986330633
# time_between_cycles: 2.120433937789824
# cycle_service_level: nan
# average_inventory: 98.58776984916162
# total_cost: 1737.2008038388547
# lead_time_demand: 0.0
# EOQ Results:
# Q: 181.55280540632504
# number_of_orders: 5.056004318470584
# time_between_cycles: 2.3734156943184614
# cycle_service_level: nan
# average_inventory: 90.77640270316252
# total_cost: 1553.11185662244
# lead_time_demand: 0.0
# EOQ Results:
# Q: 172.7393746775869
# number_of_orders: 6.346773079216681
# time_between_cycles: 1.890724601340409
# cycle_service_level: nan
# average_inventory: 86.36968733879345
# total_cost: 1938.5797987005217
# lead_time_demand: 0.0
# EOQ Results:
# Q: 158.46674042892198
# number_of_orders: 6.570956718584745
# time_between_cycles: 1.8262180857256602
# cycle_service_level: nan
# average_inventory: 79.23337021446099
# total_cost: 2002.980363661208
# lead_time_demand: 0.0
# EOQ Results:
# Q: 168.87406280973332
# number_of_orders: 6.408361343320949
# time_between_cycles: 1.872553583843533
# cycle_service_level: nan
# average_inventory: 84.43703140486666
# total_cost: 1956.2832155582312
# lead_time_demand: 0.0
# EOQ Results:
# Q: 183.80750983000107
# number_of_orders: 6.472419431424206
# time_between_cycles: 1.854020761037035
# cycle_service_level: nan
# average_inventory: 91.90375491500053
# total_cost: 1978.4873313932621
# lead_time_demand: 0.0
# EOQ Results:
# Q: 166.19585149360188
# number_of_orders: 5.869347397261993
# time_between_cycles: 2.044520316789889
# cycle_service_level: nan
# average_inventory: 83.09792574680094
# total_cost: 1794.0433894773182
# lead_time_demand: 0.0
# EOQ Results:
# Q: 159.86763573754573
# number_of_orders: 5.7836996168643395
# time_between_cycles: 2.0747965480451174
# cycle_service_level: nan
# average_inventory: 79.93381786877286
# total_cost: 1767.0834122068109
# lead_time_demand: 0.0
# EOQ Results:
# Q: 159.38479095750947
# number_of_orders: 5.716031947366451
# time_between_cycles: 2.099358455392952
# cycle_service_level: nan
# average_inventory: 79.69239547875473
# total_cost: 1746.6865424014375
# lead_time_demand: 0.0
# EOQ Results:
# Q: 163.70401379265198
# number_of_orders: 5.610241008914593
# time_between_cycles: 2.1389455427907946
# cycle_service_level: nan
# average_inventory: 81.85200689632599
# total_cost: 1715.8131054329083
# lead_time_demand: 0.0
# EOQ Results:
# Q: 171.644110583655
# number_of_orders: 5.78108870548735
# time_between_cycles: 2.0757335877945833
# cycle_service_level: nan
# average_inventory: 85.8220552918275
# total_cost: 1768.655433762936
# lead_time_demand: 0.0
# EOQ Results:
# Q: 176.6886090349205
# number_of_orders: 5.85275532548498
# time_between_cycles: 2.0503163608681416
# cycle_service_level: nan
# average_inventory: 88.34430451746024
# total_cost: 1791.1643194524777
# lead_time_demand: 0.0
# EOQ Results:
# Q: 182.60366759444724
# number_of_orders: 5.627866589270259
# time_between_cycles: 2.1322467065723365
# cycle_service_level: nan
# average_inventory: 91.30183379722362
# total_cost: 1724.8807102999674
# lead_time_demand: 0.0
# EOQ Results:
# Q: 182.81015649222056
# number_of_orders: 5.922637700655748
# time_between_cycles: 2.0261242720741426
# cycle_service_level: nan
# average_inventory: 91.40507824611028
# total_cost: 1813.3533414951683
# lead_time_demand: 0.0
# EOQ Results:
# Q: 190.16016359854865
# number_of_orders: 5.265562304109381
# time_between_cycles: 2.2789588854802627
# cycle_service_level: nan
# average_inventory: 95.08008179927432
# total_cost: 1617.7007239525242
# lead_time_demand: 0.0
# EOQ Results:
# Q: 186.28434990079816
# number_of_orders: 6.148414551870116
# time_between_cycles: 1.951722659356151
# cycle_service_level: nan
# average_inventory: 93.14217495039908
# total_cost: 1881.781235541194
# lead_time_demand: 0.0
# EOQ Results:
# Q: 180.0279398411657
# number_of_orders: 5.407684593486601
# time_between_cycles: 2.219064331979282
# cycle_service_level: nan
# average_inventory: 90.01396992058285
# total_cost: 1658.3109660142136
# lead_time_demand: 0.0
# EOQ Results:
# Q: 207.10932795274297
# number_of_orders: 6.141765459010149
# time_between_cycles: 1.9538355998918275
# cycle_service_level: nan
# average_inventory: 103.55466397637149
# total_cost: 1883.9515032935935
# lead_time_demand: 0.0
# EOQ Results:
# Q: 176.95673800898135
# number_of_orders: 6.004669540882759
# time_between_cycles: 1.9984446967977283
# cycle_service_level: nan
# average_inventory: 88.47836900449067
# total_cost: 1836.7922098666238
# lead_time_demand: 0.0
# EOQ Results:
# Q: 155.1676609584037
# number_of_orders: 5.892234494682929
# time_between_cycles: 2.0365788243540943
# cycle_service_level: nan
# average_inventory: 77.58383047920185
# total_cost: 1798.7038805965592
# lead_time_demand: 0.0
# EOQ Results:
# Q: 156.634278648972
# number_of_orders: 5.700608818807549
# time_between_cycles: 2.1050383180844454
# cycle_service_level: nan
# average_inventory: 78.317139324486
# total_cost: 1741.509501372059
# lead_time_demand: 0.0
# EOQ Results:
# Q: 193.14861553552572
# number_of_orders: 5.4271537935591105
# time_between_cycles: 2.2111037306960926
# cycle_service_level: nan
# average_inventory: 96.57430776776286
# total_cost: 1666.7758611748382
# lead_time_demand: 0.0
# EOQ Results:
# Q: 180.41880367851348
# number_of_orders: 5.418801707661728
# time_between_cycles: 2.2145117403046903
# cycle_service_level: nan
# average_inventory: 90.20940183925674
# total_cost: 1661.7242730342211
# lead_time_demand: 0.0
# EOQ Results:
# Q: 171.40066030943171
# number_of_orders: 6.250851353051952
# time_between_cycles: 1.9197384999630571
# cycle_service_level: nan
# average_inventory: 85.70033015471586
# total_cost: 1909.5355379774721
# lead_time_demand: 0.0
# EOQ Results:
# Q: 186.662778862082
# number_of_orders: 5.610779871819983
# time_between_cycles: 2.1387401170859923
# cycle_service_level: nan
# average_inventory: 93.331389431041
# total_cost: 1720.5665173184113
# lead_time_demand: 0.0
# EOQ Results:
# Q: 174.5447732630313
# number_of_orders: 5.687463967989072
# time_between_cycles: 2.1099034767587046
# cycle_service_level: nan
# average_inventory: 87.27238663151564
# total_cost: 1741.148145049328
# lead_time_demand: 0.0
# EOQ Results:
# Q: 161.33178918503188
# number_of_orders: 5.673529270436441
# time_between_cycles: 2.1150855892344573
# cycle_service_level: nan
# average_inventory: 80.66589459251594
# total_cost: 1734.3251389679383
# lead_time_demand: 0.0
# EOQ Results:
# Q: 167.88302175150915
# number_of_orders: 5.0542054144542226
# time_between_cycles: 2.374260445703673
# cycle_service_level: nan
# average_inventory: 83.94151087575457
# total_cost: 1549.8382286865685
# lead_time_demand: 0.0
# EOQ Results:
# Q: 168.40900634363314
# number_of_orders: 5.672787492397765
# time_between_cycles: 2.115362159446565
# cycle_service_level: nan
# average_inventory: 84.20450317181657
# total_cost: 1735.518048988056
# lead_time_demand: 0.0
# EOQ Results:
# Q: 193.86295037104577
# number_of_orders: 5.600037951318067
# time_between_cycles: 2.1428426207675235
# cycle_service_level: nan
# average_inventory: 96.93147518552288
# total_cost: 1718.7839754696292
# lead_time_demand: 0.0
# EOQ Results:
# Q: 180.5627731664552
# number_of_orders: 5.656810407267144
# time_between_cycles: 2.1213367845215285
# cycle_service_level: nan
# average_inventory: 90.2813865832276
# total_cost: 1733.1556768134342
# lead_time_demand: 0.0
# EOQ Results:
# Q: 159.5273378768707
# number_of_orders: 5.487624464745275
# time_between_cycles: 2.186738556381339
# cycle_service_level: nan
# average_inventory: 79.76366893843534
# total_cost: 1678.1928069989567
# lead_time_demand: 0.0
# EOQ Results:
# Q: 190.53217535993738
# number_of_orders: 5.3393506407161215
# time_between_cycles: 2.2474643093285485
# cycle_service_level: nan
# average_inventory: 95.26608767996869
# total_cost: 1639.9116272868241
# lead_time_demand: 0.0
# EOQ Results:
# Q: 172.74695091728444
# number_of_orders: 6.011867257038642
# time_between_cycles: 1.996052056197765
# cycle_service_level: nan
# average_inventory: 86.37347545864222
# total_cost: 1838.1095672950498
# lead_time_demand: 0.0
# EOQ Results:
# Q: 165.53621857059662
# number_of_orders: 5.507038062435312
# time_between_cycles: 2.179029791323684
# cycle_service_level: nan
# average_inventory: 82.76810928529831
# total_cost: 1685.2186624447127
# lead_time_demand: 0.0
# EOQ Results:
# Q: 169.90096845369538
# number_of_orders: 5.976260876177885
# time_between_cycles: 2.007944473748374
# cycle_service_level: nan
# average_inventory: 84.95048422684769
# total_cost: 1826.8584565441045
# lead_time_demand: 0.0
# EOQ Results:
# Q: 171.79572493323178
# number_of_orders: 5.854749134389177
# time_between_cycles: 2.049618134706288
# cycle_service_level: nan
# average_inventory: 85.89786246661589
# total_cost: 1790.7838853033995
# lead_time_demand: 0.0
# EOQ Results:
# Q: 152.91017382764943
# number_of_orders: 5.792308961830398
# time_between_cycles: 2.071712693344994
# cycle_service_level: nan
# average_inventory: 76.45508691382472
# total_cost: 1768.2747233146492
# lead_time_demand: 0.0
# EOQ Results:
# Q: 175.18293254576275
# number_of_orders: 5.912555070193574
# time_between_cycles: 2.0295794047643647
# cycle_service_level: nan
# average_inventory: 87.59146627288138
# total_cost: 1808.8031075672247
# lead_time_demand: 0.0
# EOQ Results:
# Q: 181.9446380002968
# number_of_orders: 5.804394480892043
# time_between_cycles: 2.067399112776324
# cycle_service_level: nan
# average_inventory: 90.9723190001484
# total_cost: 1777.707271867672
# lead_time_demand: 0.0
# EOQ Results:
# Q: 181.2386210704775
# number_of_orders: 6.115170805049028
# time_between_cycles: 1.9623327593878697
# cycle_service_level: nan
# average_inventory: 90.61931053523875
# total_cost: 1870.7989657288042
# lead_time_demand: 0.0
# EOQ Results:
# Q: 177.34878905354918
# number_of_orders: 6.232803793600918
# time_between_cycles: 1.9252972494209002
# cycle_service_level: nan
# average_inventory: 88.67439452677459
# total_cost: 1905.3108958909852
# lead_time_demand: 0.0
# EOQ Results:
# Q: 160.44070591226716
# number_of_orders: 5.374154010988836
# time_between_cycles: 2.2329095845528286
# cycle_service_level: nan
# average_inventory: 80.22035295613358
# total_cost: 1644.3343444791042
# lead_time_demand: 0.0
# EOQ Results:
# Q: 164.54973812018804
# number_of_orders: 5.50725577786445
# time_between_cycles: 2.178943648891725
# cycle_service_level: nan
# average_inventory: 82.27486906009402
# total_cost: 1685.0866809833724
# lead_time_demand: 0.0
# EOQ Results:
# Q: 184.19211262326868
# number_of_orders: 5.708732647371955
# time_between_cycles: 2.1020427371956654
# cycle_service_level: nan
# average_inventory: 92.09605631163434
# total_cost: 1749.45821673624
# lead_time_demand: 0.0
# EOQ Results:
# Q: 183.79521862053903
# number_of_orders: 5.720380557134525
# time_between_cycles: 2.097762531731121
# cycle_service_level: nan
# average_inventory: 91.89760931026952
# total_cost: 1752.8732108644656
# lead_time_demand: 0.0
# EOQ Results:
# Q: 191.5502915188925
# number_of_orders: 5.489444888299193
# time_between_cycles: 2.186013384628038
# cycle_service_level: nan
# average_inventory: 95.77514575944625
# total_cost: 1685.1435247935365
# lead_time_demand: 0.0
# EOQ Results:
# Q: 188.06900392574505
# number_of_orders: 7.365770648800889
# time_between_cycles: 1.6291574326921978
# cycle_service_level: nan
# average_inventory: 94.03450196287253
# total_cost: 2247.344995425416
# lead_time_demand: 0.0
# EOQ Results:
# Q: 190.3093590116617
# number_of_orders: 5.554582583637101
# time_between_cycles: 2.160378357745558
# cycle_service_level: nan
# average_inventory: 95.15467950583086
# total_cost: 1704.4366468934625
# lead_time_demand: 0.0
# EOQ Results:
# Q: 189.45658276904996
# number_of_orders: 5.877634589110581
# time_between_cycles: 2.041637638078462
# cycle_service_level: nan
# average_inventory: 94.72829138452498
# total_cost: 1801.1816932869842
# lead_time_demand: 0.0
# EOQ Results:
# Q: 188.1636706271649
# number_of_orders: 5.821528527256414
# time_between_cycles: 2.0613142998124916
# cycle_service_level: nan
# average_inventory: 94.08183531358245
# total_cost: 1784.0912923023573
# lead_time_demand: 0.0
# EOQ Results:
# Q: 171.2583226624007
# number_of_orders: 6.21948824776402
# ...
# lead_time_demand: 0.0
# EOQ Results:
# Q: 179.74055262987193
# number_of_orders: 5.254685342353357
# time_between_cycles: 2.2836762276284457
# cycle_service_level: nan
# average_inventory: 89.87027631493596
# total_cost: 1612.3537132319814
# lead_time_demand: 0.0
# EOQ Results:
# Q: 184.2738118034743
# number_of_orders: 6.447555924067872
# time_between_cycles: 1.8611703630527017
# cycle_service_level: nan
# average_inventory: 92.13690590173715
# total_cost: 1971.1215395810566
# lead_time_demand: 0.0
# EOQ Results:
# Q: 164.0366313994094
# number_of_orders: 5.213461180363246
# time_between_cycles: 2.3017338357094865
# cycle_service_level: nan
# average_inventory: 82.0183156997047
# total_cost: 1596.8456803888555
# lead_time_demand: 0.0
# EOQ Results:
# Q: 153.79920164726602
# number_of_orders: 5.072324147216141
# time_between_cycles: 2.3657794044148375
# cycle_service_level: nan
# average_inventory: 76.89960082363301
# total_cost: 1552.4570844942955
# lead_time_demand: 0.0
# EOQ Results:
# Q: 157.38489082220067
# number_of_orders: 6.63342865729565
# time_between_cycles: 1.8090192297164496
# cycle_service_level: nan
# average_inventory: 78.69244541110034
# total_cost: 2021.5055753531353
# lead_time_demand: 0.0
# EOQ Results:
# Q: 183.12258186489447
# number_of_orders: 5.1866600388229855
# time_between_cycles: 2.313627635159827
# cycle_service_level: nan
# average_inventory: 91.56129093244724
# total_cost: 1592.6225280198746
# lead_time_demand: 0.0
# EOQ Results:
# Q: 162.07940708864234
# number_of_orders: 5.53973348258779
# time_between_cycles: 2.16616919166198
# cycle_service_level: nan
# average_inventory: 81.03970354432117
# total_cost: 1694.3359261940655
# lead_time_demand: 0.0
# EOQ Results:
# Q: 175.18484966697406
# number_of_orders: 6.112604182185794
# time_between_cycles: 1.9631567237695644
# cycle_service_level: nan
# average_inventory: 87.59242483348703
# total_cost: 1868.818224589133
# lead_time_demand: 0.0
# EOQ Results:
# Q: 166.49758406159486
# number_of_orders: 6.152522135084892
# time_between_cycles: 1.9504196387315273
# cycle_service_level: nan
# average_inventory: 83.24879203079743
# total_cost: 1879.0561573377865
# lead_time_demand: 0.0
# EOQ Results:
# Q: 167.43084267966702
# number_of_orders: 5.6357127625023775
# time_between_cycles: 2.129278142037839
# cycle_service_level: nan
# average_inventory: 83.71542133983351
# total_cost: 1724.1999972866465
# lead_time_demand: 0.0
# EOQ Results:
# Q: 159.3026571701715
# number_of_orders: 5.473666137291412
# time_between_cycles: 2.192314930982999
# cycle_service_level: nan
# average_inventory: 79.65132858508575
# total_cost: 1673.9603726214577
# lead_time_demand: 0.0
# EOQ Results:
# Q: 184.24683811847436
# number_of_orders: 5.901027903278829
# time_between_cycles: 2.0335440192262704
# cycle_service_level: nan
# average_inventory: 92.12341905923718
# total_cost: 1807.1577386073434
# lead_time_demand: 0.0
# EOQ Results:
# Q: 176.38951736114473
# number_of_orders: 6.037887816288508
# time_between_cycles: 1.9874499767331557
# cycle_service_level: nan
# average_inventory: 88.19475868057236
# total_cost: 1846.6442483587816
# lead_time_demand: 0.0
# EOQ Results:
# Q: 175.37977493439038
# number_of_orders: 5.64536255102649
# time_between_cycles: 2.1256385026711975
# cycle_service_level: nan
# average_inventory: 87.68988746719519
# total_cost: 1728.6847202948247
# lead_time_demand: 0.0
# EOQ Results:
# Q: 182.92108613435633
# number_of_orders: 6.476364888488723
# time_between_cycles: 1.8528912756798408
# cycle_service_level: nan
# average_inventory: 91.46054306717816
# total_cost: 1979.493683773488
# lead_time_demand: 0.0
# EOQ Results:
# Q: 166.78706472710104
# number_of_orders: 5.354081414098317
# time_between_cycles: 2.2412808233363264
# cycle_service_level: nan
# average_inventory: 83.39353236355052
# total_cost: 1639.5818371749153
# lead_time_demand: 0.0
# EOQ Results:
# Q: 156.52330706803346
# number_of_orders: 5.41419357143521
# time_between_cycles: 2.216396558724997
# cycle_service_level: nan
# average_inventory: 78.26165353401673
# total_cost: 1655.5627328441697
# lead_time_demand: 0.0
# EOQ Results:
# Q: 167.35061965559586
# number_of_orders: 5.5620301551763704
# time_between_cycles: 2.1574856060124117
# cycle_service_level: nan
# average_inventory: 83.67530982779793
# total_cost: 1702.0791704840303
# lead_time_demand: 0.0
# EOQ Results:
# Q: 163.8317113827039
# number_of_orders: 6.0759995117132215
# time_between_cycles: 1.9749837005198203
# cycle_service_level: nan
# average_inventory: 81.91585569135195
# total_cost: 1855.5661957905072
# lead_time_demand: 0.0
# EOQ Results:
# Q: 175.75200489451115
# number_of_orders: 5.828291663284802
# time_between_cycles: 2.0589223555152087
# cycle_service_level: nan
# average_inventory: 87.87600244725557
# total_cost: 1783.637899964343
# lead_time_demand: 0.0
# EOQ Results:
# Q: 188.6418913671788
# number_of_orders: 5.173169051379415
# time_between_cycles: 2.3196612909450978
# cycle_service_level: nan
# average_inventory: 94.3209456835894
# total_cost: 1589.6790936872603
# lead_time_demand: 0.0
# EOQ Results:
# Q: 166.06100927241533
# number_of_orders: 6.233886835850933
# time_between_cycles: 1.9249627585454854
# cycle_service_level: nan
# average_inventory: 83.03050463620767
# total_cost: 1903.378252609763
# lead_time_demand: 0.0
# EOQ Results:
# Q: 169.88012813935308
# number_of_orders: 5.149784540210126
# time_between_cycles: 2.330194575385161
# cycle_service_level: nan
# average_inventory: 84.94006406967654
# total_cost: 1578.9113876909082
# lead_time_demand: 0.0
# EOQ Results:
# Q: 191.65791889363013
# number_of_orders: 5.970932310093867
# time_between_cycles: 2.009736399073556
# cycle_service_level: nan
# average_inventory: 95.82895944681506
# total_cost: 1829.6112768068863
# lead_time_demand: 0.0
# EOQ Results:
# Q: 177.87103749548078
# number_of_orders: 5.575864941957971
# time_between_cycles: 2.152132471807358
# cycle_service_level: nan
# average_inventory: 88.93551874774039
# total_cost: 1708.3336900864874
# lead_time_demand: 0.0
# EOQ Results:
# Q: 171.2360625110261
# number_of_orders: 6.492379974499982
# time_between_cycles: 1.8483206539254033
# cycle_service_level: nan
# average_inventory: 85.61803125551305
# total_cost: 1981.9612048521997
# lead_time_demand: 0.0
# EOQ Results:
# Q: 198.63115835682012
# number_of_orders: 5.207000468576072
# time_between_cycles: 2.304589767644398
# cycle_service_level: nan
# average_inventory: 99.31557917841006
# total_cost: 1601.8263722441857
# lead_time_demand: 0.0
# EOQ Results:
# Q: 154.52494022996896
# number_of_orders: 6.767032689733909
# time_between_cycles: 1.7733030931274931
# cycle_service_level: nan
# average_inventory: 77.26247011498448
# total_cost: 2061.0147949661664
# lead_time_demand: 0.0
# EOQ Results:
# Q: 169.3531227949591
# number_of_orders: 6.241259154712687
# time_between_cycles: 1.9226889482611802
# cycle_service_level: nan
# average_inventory: 84.67656139747955
# total_cost: 1906.2483709727983
# lead_time_demand: 0.0
# EOQ Results:
# Q: 175.09627094512223
# number_of_orders: 5.966836702816922
# time_between_cycles: 2.011115872223358
# cycle_service_level: nan
# average_inventory: 87.54813547256111
# total_cost: 1825.070265034101
# lead_time_demand: 0.0
# EOQ Results:
# Q: 179.17701355627682
# number_of_orders: 5.939781308233952
# time_between_cycles: 2.0202764003053684
# cycle_service_level: nan
# average_inventory: 89.58850677813841
# total_cost: 1817.769795181441
# lead_time_demand: 0.0
# EOQ Results:
# Q: 181.7797465051319
# number_of_orders: 6.232351374641505
# time_between_cycles: 1.9254370106323249
# cycle_service_level: nan
# average_inventory: 90.88987325256595
# total_cost: 1906.0613616934777
# lead_time_demand: 0.0
# EOQ Results:
# Q: 170.51225693429015
# number_of_orders: 5.979934435816468
# time_between_cycles: 2.0067109646096952
# cycle_service_level: nan
# average_inventory: 85.25612846714507
# total_cost: 1828.0827821317987
# lead_time_demand: 0.0
# EOQ Results:
# Q: 173.7232446986633
# number_of_orders: 6.164404640360088
# time_between_cycles: 1.9466600101869742
# cycle_service_level: nan
# average_inventory: 86.86162234933165
# total_cost: 1884.0660410477592
# lead_time_demand: 0.0
# EOQ Results:
# Q: 167.82694608587323
# number_of_orders: 5.905049538732544
# time_between_cycles: 2.0321590735673443
# cycle_service_level: nan
# average_inventory: 83.91347304293662
# total_cost: 1805.0802508369381
# lead_time_demand: 0.0
# EOQ Results:
# Q: 184.43328672049705
# number_of_orders: 6.20284842225179
# time_between_cycles: 1.934595073603894
# cycle_service_level: nan
# average_inventory: 92.21664336024853
# total_cost: 1897.7411840196366
# lead_time_demand: 0.0
# EOQ Results:
# Q: 168.91982329254017
# number_of_orders: 5.519546206127531
# time_between_cycles: 2.1740917734646708
# cycle_service_level: nan
# average_inventory: 84.45991164627009
# total_cost: 1689.6478264967673
# lead_time_demand: 0.0
# EOQ Results:
# Q: 189.59587885656927
# number_of_orders: 6.224259991346287
# time_between_cycles: 1.9279400308926427
# cycle_service_level: nan
# average_inventory: 94.79793942828464
# total_cost: 1905.1971731752
# lead_time_demand: 0.0
# EOQ Results:
# Q: 174.56654747279305
# number_of_orders: 5.7054700305096775
# time_between_cycles: 2.1032447696387293
# cycle_service_level: nan
# average_inventory: 87.28327373639652
# total_cost: 1746.5543186474622
# lead_time_demand: 0.0
# EOQ Results:
# Q: 151.95334794979982
# number_of_orders: 5.639378805074391
# time_between_cycles: 2.1278939427162147
# cycle_service_level: nan
# average_inventory: 75.97667397489991
# total_cost: 1722.2043111122773
# lead_time_demand: 0.0
# EOQ Results:
# Q: 169.35725824968364
# number_of_orders: 5.980319071993307
# time_between_cycles: 2.0065818989822337
# cycle_service_level: nan
# average_inventory: 84.67862912484182
# total_cost: 1827.9671732479287
# lead_time_demand: 0.0
# EOQ Results:
# Q: 199.0002778195229
# number_of_orders: 4.682882076665566
# time_between_cycles: 2.56252448888155
# cycle_service_level: nan
# average_inventory: 99.50013890976145
# total_cost: 1444.6646785635744
# lead_time_demand: 0.0
# EOQ Results:
# Q: 174.7000686884387
# number_of_orders: 6.205288658656455
# time_between_cycles: 1.933834292021186
# cycle_service_level: nan
# average_inventory: 87.35003434421935
# total_cost: 1896.526611334624
# lead_time_demand: 0.0
# EOQ Results:
# Q: 165.85076842878647
# number_of_orders: 5.636016106076237
# time_between_cycles: 2.129163539306195
# cycle_service_level: nan
# average_inventory: 82.92538421439323
# total_cost: 1723.9749855086284
# lead_time_demand: 0.0
# EOQ Results:
# Q: 169.4555169260832
# number_of_orders: 5.637949557554159
# time_between_cycles: 2.128433374137141
# cycle_service_level: nan
# average_inventory: 84.7277584630416
# total_cost: 1725.2759706514646
# lead_time_demand: 0.0
# EOQ Results:
# Q: 159.1065954791125
# number_of_orders: 5.0975003547978055
# time_between_cycles: 2.3540949808283016
# cycle_service_level: nan
# average_inventory: 79.55329773955626
# total_cost: 1561.0714255351638
# lead_time_demand: 0.0
# EOQ Results:
# Q: 160.46383797291796
# number_of_orders: 5.9500594036410375
# time_between_cycles: 2.0167865874846234
# cycle_service_level: nan
# average_inventory: 80.23191898645898
# total_cost: 1817.110588686895
# lead_time_demand: 0.0
# EOQ Results:
# Q: 144.08742075532854
# number_of_orders: 5.258002838593298
# time_between_cycles: 2.2822353597683533
# cycle_service_level: nan
# average_inventory: 72.04371037766427
# total_cost: 1606.218335729055
# lead_time_demand: 0.0
# EOQ Results:
# Q: 165.41803549282955
# number_of_orders: 5.087774831468781
# time_between_cycles: 2.358594945235762
# cycle_service_level: nan
# average_inventory: 82.70901774641477
# total_cost: 1559.4160565392
# lead_time_demand: 0.0
# EOQ Results:
# Q: 176.1210486926795
# number_of_orders: 6.1096698753597405
# time_between_cycles: 1.9640995740859786
# cycle_service_level: nan
# average_inventory: 88.06052434633975
# total_cost: 1868.1251723464577
# lead_time_demand: 0.0
# EOQ Results:
# Q: 189.3140212663888
# number_of_orders: 5.69730656319103
# time_between_cycles: 2.1062584340342863
# cycle_service_level: nan
# average_inventory: 94.6570106331944
# total_cost: 1747.054773210587
# lead_time_demand: 0.0
# EOQ Results:
# Q: 190.47805080001157
# number_of_orders: 5.473311763742771
# time_between_cycles: 2.192456874006778
# cycle_service_level: nan
# average_inventory: 95.23902540000579
# total_cost: 1680.0891392828335
# lead_time_demand: 0.0
# EOQ Results:
# Q: 170.03226747512986
# number_of_orders: 5.312535079961821
# time_between_cycles: 2.2588086138503654
# cycle_service_level: nan
# average_inventory: 85.01613373756493
# total_cost: 1627.7669774835724
# lead_time_demand: 0.0
# EOQ Results:
# Q: 165.79038643146902
# number_of_orders: 6.002934704523347
# time_between_cycles: 1.999022243396672
# cycle_service_level: nan
# average_inventory: 82.89519321573451
# total_cost: 1834.0384886432978
# lead_time_demand: 0.0
# EOQ Results:
# Q: 165.4677502849317
# number_of_orders: 6.041296532826404
# time_between_cycles: 1.9863285860569788
# cycle_service_level: nan
# average_inventory: 82.73387514246585
# total_cost: 1845.4825099049076
# lead_time_demand: 0.0
# EOQ Results:
# Q: 158.8407136555289
# number_of_orders: 5.566353302832633
# time_between_cycles: 2.155809979559397
# cycle_service_level: nan
# average_inventory: 79.42035682776445
# total_cost: 1701.6741335808956
# lead_time_demand: 0.0
# EOQ Results:
# Q: 179.37962684815508
# number_of_orders: 6.412878933851714
# time_between_cycles: 1.8712344523854187
# cycle_service_level: nan
# average_inventory: 89.68981342407754
# total_cost: 1959.7396055251452
# lead_time_demand: 0.0
# EOQ Results:
# Q: 176.15438319167913
# number_of_orders: 6.174902999001548
# time_between_cycles: 1.943350365494056
# cycle_service_level: nan
# average_inventory: 88.07719159583957
# total_cost: 1887.7017763387998
# lead_time_demand: 0.0
# EOQ Results:
# Q: 177.05373655235422
# number_of_orders: 5.523202173865846
# time_between_cycles: 2.1726526790528222
# cycle_service_level: nan
# average_inventory: 88.52686827617711
# total_cost: 1692.3713994702246
# lead_time_demand: 0.0
# EOQ Results:
# Q: 169.8093054335261
# number_of_orders: 5.904791738824747
# time_between_cycles: 2.0322477964969523
# cycle_service_level: nan
# average_inventory: 84.90465271676305
# total_cost: 1805.3993827341294
# lead_time_demand: 0.0
# EOQ Results:
# Q: 168.39104399293717
# number_of_orders: 6.062307451681173
# time_between_cycles: 1.9794443115339213
# cycle_service_level: nan
# average_inventory: 84.19552199646859
# total_cost: 1852.3704443029396
# lead_time_demand: 0.0
# EOQ Results:
# Q: 148.99748253014036
# number_of_orders: 5.341207781793125
# time_between_cycles: 2.2466828646706225
# cycle_service_level: nan
# average_inventory: 74.49874126507018
# total_cost: 1632.161831043966
# lead_time_demand: 0.0
# EOQ Results:
# Q: 161.7081223398463
# number_of_orders: 6.031127241081212
# time_between_cycles: 1.9896778032241842
# cycle_service_level: nan
# average_inventory: 80.85406116992316
# total_cost: 1841.679796792333
# lead_time_demand: 0.0
# EOQ Results:
# Q: 161.57047606485133
# number_of_orders: 5.767152501464516
# time_between_cycles: 2.0807495548197674
# cycle_service_level: nan
# average_inventory: 80.78523803242567
# total_cost: 1762.4598456523252
# lead_time_demand: 0.0
# EOQ Results:
# Q: 161.48873592905363
# number_of_orders: 5.572140953569861
# time_between_cycles: 2.1535707908307757
# cycle_service_level: nan
# average_inventory: 80.74436796452682
# total_cost: 1703.940033256769
# lead_time_demand: 0.0
# EOQ Results:
# Q: 162.29024659212706
# number_of_orders: 5.988591373294224
# time_between_cycles: 2.003810120275246
# cycle_service_level: nan
# average_inventory: 81.14512329606353
# total_cost: 1829.0354613066925
# lead_time_demand: 0.0
# EOQ Results:
# Q: 188.3804024842454
# number_of_orders: 6.26269313116909
# time_between_cycles: 1.9161085732073697
# cycle_service_level: nan
# average_inventory: 94.1902012421227
# total_cost: 1916.484019847576
# lead_time_demand: 0.0
# EOQ Results:
# Q: 187.1095107265227
# number_of_orders: 5.686959909172952
# time_between_cycles: 2.1100904862445473
# cycle_service_level: nan
# average_inventory: 93.55475536326135
# total_cost: 1743.5098748971902
# lead_time_demand: 0.0
# EOQ Results:
# Q: 169.57407846651378
# number_of_orders: 5.560296181753473
# time_between_cycles: 2.1581584159813096
# cycle_service_level: nan
# average_inventory: 84.78703923325689
# total_cost: 1702.0036702193445
# lead_time_demand: 0.0
# EOQ Results:
# Q: 185.12312751708032
# number_of_orders: 5.711108559561627
# time_between_cycles: 2.1011682539127037
# cycle_service_level: nan
# average_inventory: 92.56156375854016
# total_cost: 1750.3571933719043
# lead_time_demand: 0.0
# C:\Users\Asus\AppData\Local\Temp\ipykernel_8604\628146779.py:53: RuntimeWarning: invalid value encountered in double_scalars
#   cycle_service_level = 1 - norm.cdf((safety_stock - lead_time * (D / 12)) / demand_variation)

# %%
# Print the EOQ results for each scenario
for i, result in enumerate(eoq_results, 1):
    print(f"\nScenario {i} - EOQ Results:")
    print(f"Optimal Order Quantity (Q): {result['Q']:.2f}")
    print(f"Number of Orders per Year: {result['number_of_orders']:.2f}")
    print(f"Time Between Orders (Months): {result['time_between_cycles']:.2f}")
    print(f"Cycle Service Level: {result['cycle_service_level']:.2%}")
    print(f"Average Inventory Level: {result['average_inventory']:.2f}")
    print(f"Total Cost per Year: {result['total_cost']:.2f}")
    print(f"Lead Time Demand: {result['lead_time_demand']:.2f}")
    print("-" * 50)
# Out:
# Scenario 1 - EOQ Results:
# Optimal Order Quantity (Q): 166.21
# Number of Orders per Year: 6.32
# Time Between Orders (Months): 1.90
# Cycle Service Level: nan%
# Average Inventory Level: 83.10
# Total Cost per Year: 1927.88
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 2 - EOQ Results:
# Optimal Order Quantity (Q): 164.56
# Number of Orders per Year: 5.99
# Time Between Orders (Months): 2.00
# Cycle Service Level: nan%
# Average Inventory Level: 82.28
# Total Cost per Year: 1830.71
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 3 - EOQ Results:
# Optimal Order Quantity (Q): 178.20
# Number of Orders per Year: 5.98
# Time Between Orders (Months): 2.01
# Cycle Service Level: nan%
# Average Inventory Level: 89.10
# Total Cost per Year: 1828.22
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 4 - EOQ Results:
# Optimal Order Quantity (Q): 192.25
# Number of Orders per Year: 5.99
# Time Between Orders (Months): 2.00
# Cycle Service Level: nan%
# Average Inventory Level: 96.13
# Total Cost per Year: 1836.58
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 5 - EOQ Results:
# Optimal Order Quantity (Q): 165.49
# Number of Orders per Year: 5.90
# Time Between Orders (Months): 2.03
# Cycle Service Level: nan%
# Average Inventory Level: 82.74
# Total Cost per Year: 1803.50
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 6 - EOQ Results:
# Optimal Order Quantity (Q): 167.89
# Number of Orders per Year: 5.82
# Time Between Orders (Months): 2.06
# Cycle Service Level: nan%
# Average Inventory Level: 83.95
# Total Cost per Year: 1778.58
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 7 - EOQ Results:
# Optimal Order Quantity (Q): 178.56
# Number of Orders per Year: 6.48
# Time Between Orders (Months): 1.85
# Cycle Service Level: nan%
# Average Inventory Level: 89.28
# Total Cost per Year: 1981.15
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 8 - EOQ Results:
# Optimal Order Quantity (Q): 174.28
# Number of Orders per Year: 6.18
# Time Between Orders (Months): 1.94
# Cycle Service Level: nan%
# Average Inventory Level: 87.14
# Total Cost per Year: 1888.34
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 9 - EOQ Results:
# Optimal Order Quantity (Q): 160.86
# Number of Orders per Year: 5.92
# Time Between Orders (Months): 2.03
# Cycle Service Level: nan%
# Average Inventory Level: 80.43
# Total Cost per Year: 1809.60
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 10 - EOQ Results:
# Optimal Order Quantity (Q): 182.80
# Number of Orders per Year: 5.77
# Time Between Orders (Months): 2.08
# Cycle Service Level: nan%
# Average Inventory Level: 91.40
# Total Cost per Year: 1766.73
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 11 - EOQ Results:
# Optimal Order Quantity (Q): 159.00
# Number of Orders per Year: 6.00
# Time Between Orders (Months): 2.00
# Cycle Service Level: nan%
# Average Inventory Level: 79.50
# Total Cost per Year: 1831.21
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 12 - EOQ Results:
# Optimal Order Quantity (Q): 167.48
# Number of Orders per Year: 5.69
# Time Between Orders (Months): 2.11
# Cycle Service Level: nan%
# Average Inventory Level: 83.74
# Total Cost per Year: 1741.36
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 13 - EOQ Results:
# Optimal Order Quantity (Q): 159.52
# Number of Orders per Year: 6.42
# Time Between Orders (Months): 1.87
# Cycle Service Level: nan%
# Average Inventory Level: 79.76
# Total Cost per Year: 1958.10
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 14 - EOQ Results:
# Optimal Order Quantity (Q): 161.42
# Number of Orders per Year: 5.01
# Time Between Orders (Months): 2.40
# Cycle Service Level: nan%
# Average Inventory Level: 80.71
# Total Cost per Year: 1535.22
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 15 - EOQ Results:
# Optimal Order Quantity (Q): 145.44
# Number of Orders per Year: 5.69
# Time Between Orders (Months): 2.11
# Cycle Service Level: nan%
# Average Inventory Level: 72.72
# Total Cost per Year: 1735.98
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 16 - EOQ Results:
# Optimal Order Quantity (Q): 166.62
# Number of Orders per Year: 5.66
# Time Between Orders (Months): 2.12
# Cycle Service Level: nan%
# Average Inventory Level: 83.31
# Total Cost per Year: 1732.54
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 17 - EOQ Results:
# Optimal Order Quantity (Q): 169.82
# Number of Orders per Year: 5.29
# Time Between Orders (Months): 2.27
# Cycle Service Level: nan%
# Average Inventory Level: 84.91
# Total Cost per Year: 1621.58
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 18 - EOQ Results:
# Optimal Order Quantity (Q): 180.32
# Number of Orders per Year: 5.72
# Time Between Orders (Months): 2.10
# Cycle Service Level: nan%
# Average Inventory Level: 90.16
# Total Cost per Year: 1752.03
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 19 - EOQ Results:
# Optimal Order Quantity (Q): 167.86
# Number of Orders per Year: 5.42
# Time Between Orders (Months): 2.22
# Cycle Service Level: nan%
# Average Inventory Level: 83.93
# Total Cost per Year: 1658.45
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 20 - EOQ Results:
# Optimal Order Quantity (Q): 157.21
# Number of Orders per Year: 5.46
# Time Between Orders (Months): 2.20
# Cycle Service Level: nan%
# Average Inventory Level: 78.60
# Total Cost per Year: 1670.22
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 21 - EOQ Results:
# Optimal Order Quantity (Q): 180.80
# Number of Orders per Year: 6.34
# Time Between Orders (Months): 1.89
# Cycle Service Level: nan%
# Average Inventory Level: 90.40
# Total Cost per Year: 1938.67
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 22 - EOQ Results:
# Optimal Order Quantity (Q): 176.37
# Number of Orders per Year: 5.54
# Time Between Orders (Months): 2.17
# Cycle Service Level: nan%
# Average Inventory Level: 88.19
# Total Cost per Year: 1697.82
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 23 - EOQ Results:
# Optimal Order Quantity (Q): 174.00
# Number of Orders per Year: 5.79
# Time Between Orders (Months): 2.07
# Cycle Service Level: nan%
# Average Inventory Level: 87.00
# Total Cost per Year: 1770.57
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 24 - EOQ Results:
# Optimal Order Quantity (Q): 145.56
# Number of Orders per Year: 5.89
# Time Between Orders (Months): 2.04
# Cycle Service Level: nan%
# Average Inventory Level: 72.78
# Total Cost per Year: 1796.51
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 25 - EOQ Results:
# Optimal Order Quantity (Q): 155.53
# Number of Orders per Year: 6.08
# Time Between Orders (Months): 1.97
# Cycle Service Level: nan%
# Average Inventory Level: 77.76
# Total Cost per Year: 1855.04
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 26 - EOQ Results:
# Optimal Order Quantity (Q): 170.48
# Number of Orders per Year: 5.93
# Time Between Orders (Months): 2.02
# Cycle Service Level: nan%
# Average Inventory Level: 85.24
# Total Cost per Year: 1813.32
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 27 - EOQ Results:
# Optimal Order Quantity (Q): 162.62
# Number of Orders per Year: 5.44
# Time Between Orders (Months): 2.21
# Cycle Service Level: nan%
# Average Inventory Level: 81.31
# Total Cost per Year: 1664.94
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 28 - EOQ Results:
# Optimal Order Quantity (Q): 175.38
# Number of Orders per Year: 5.92
# Time Between Orders (Months): 2.03
# Cycle Service Level: nan%
# Average Inventory Level: 87.69
# Total Cost per Year: 1809.92
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 29 - EOQ Results:
# Optimal Order Quantity (Q): 163.00
# Number of Orders per Year: 5.77
# Time Between Orders (Months): 2.08
# Cycle Service Level: nan%
# Average Inventory Level: 81.50
# Total Cost per Year: 1762.57
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 30 - EOQ Results:
# Optimal Order Quantity (Q): 180.12
# Number of Orders per Year: 5.39
# Time Between Orders (Months): 2.23
# Cycle Service Level: nan%
# Average Inventory Level: 90.06
# Total Cost per Year: 1653.00
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 31 - EOQ Results:
# Optimal Order Quantity (Q): 170.12
# Number of Orders per Year: 5.52
# Time Between Orders (Months): 2.17
# Cycle Service Level: nan%
# Average Inventory Level: 85.06
# Total Cost per Year: 1691.41
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 32 - EOQ Results:
# Optimal Order Quantity (Q): 206.59
# Number of Orders per Year: 5.74
# Time Between Orders (Months): 2.09
# Cycle Service Level: nan%
# Average Inventory Level: 103.29
# Total Cost per Year: 1762.48
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 33 - EOQ Results:
# Optimal Order Quantity (Q): 169.73
# Number of Orders per Year: 5.88
# Time Between Orders (Months): 2.04
# Cycle Service Level: nan%
# Average Inventory Level: 84.87
# Total Cost per Year: 1799.04
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 34 - EOQ Results:
# Optimal Order Quantity (Q): 158.73
# Number of Orders per Year: 5.63
# Time Between Orders (Months): 2.13
# Cycle Service Level: nan%
# Average Inventory Level: 79.37
# Total Cost per Year: 1721.81
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 35 - EOQ Results:
# Optimal Order Quantity (Q): 184.71
# Number of Orders per Year: 5.86
# Time Between Orders (Months): 2.05
# Cycle Service Level: nan%
# Average Inventory Level: 92.35
# Total Cost per Year: 1794.75
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 36 - EOQ Results:
# Optimal Order Quantity (Q): 150.85
# Number of Orders per Year: 5.82
# Time Between Orders (Months): 2.06
# Cycle Service Level: nan%
# Average Inventory Level: 75.43
# Total Cost per Year: 1776.11
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 37 - EOQ Results:
# Optimal Order Quantity (Q): 186.83
# Number of Orders per Year: 5.46
# Time Between Orders (Months): 2.20
# Cycle Service Level: nan%
# Average Inventory Level: 93.41
# Total Cost per Year: 1676.65
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 38 - EOQ Results:
# Optimal Order Quantity (Q): 168.10
# Number of Orders per Year: 4.78
# Time Between Orders (Months): 2.51
# Cycle Service Level: nan%
# Average Inventory Level: 84.05
# Total Cost per Year: 1468.50
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 39 - EOQ Results:
# Optimal Order Quantity (Q): 159.51
# Number of Orders per Year: 5.44
# Time Between Orders (Months): 2.21
# Cycle Service Level: nan%
# Average Inventory Level: 79.76
# Total Cost per Year: 1662.83
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 40 - EOQ Results:
# Optimal Order Quantity (Q): 166.41
# Number of Orders per Year: 6.13
# Time Between Orders (Months): 1.96
# Cycle Service Level: nan%
# Average Inventory Level: 83.20
# Total Cost per Year: 1871.59
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 41 - EOQ Results:
# Optimal Order Quantity (Q): 166.05
# Number of Orders per Year: 6.47
# Time Between Orders (Months): 1.86
# Cycle Service Level: nan%
# Average Inventory Level: 83.02
# Total Cost per Year: 1973.32
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 42 - EOQ Results:
# Optimal Order Quantity (Q): 178.83
# Number of Orders per Year: 5.69
# Time Between Orders (Months): 2.11
# Cycle Service Level: nan%
# Average Inventory Level: 89.42
# Total Cost per Year: 1742.05
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 43 - EOQ Results:
# Optimal Order Quantity (Q): 163.60
# Number of Orders per Year: 6.04
# Time Between Orders (Months): 1.99
# Cycle Service Level: nan%
# Average Inventory Level: 81.80
# Total Cost per Year: 1845.22
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 44 - EOQ Results:
# Optimal Order Quantity (Q): 170.91
# Number of Orders per Year: 5.67
# Time Between Orders (Months): 2.11
# Cycle Service Level: nan%
# Average Inventory Level: 85.45
# Total Cost per Year: 1736.67
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 45 - EOQ Results:
# Optimal Order Quantity (Q): 161.29
# Number of Orders per Year: 5.28
# Time Between Orders (Months): 2.27
# Cycle Service Level: nan%
# Average Inventory Level: 80.64
# Total Cost per Year: 1617.28
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 46 - EOQ Results:
# Optimal Order Quantity (Q): 159.94
# Number of Orders per Year: 5.80
# Time Between Orders (Months): 2.07
# Cycle Service Level: nan%
# Average Inventory Level: 79.97
# Total Cost per Year: 1772.69
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 47 - EOQ Results:
# Optimal Order Quantity (Q): 163.91
# Number of Orders per Year: 5.82
# Time Between Orders (Months): 2.06
# Cycle Service Level: nan%
# Average Inventory Level: 81.95
# Total Cost per Year: 1778.77
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 48 - EOQ Results:
# Optimal Order Quantity (Q): 198.44
# Number of Orders per Year: 5.57
# Time Between Orders (Months): 2.15
# Cycle Service Level: nan%
# Average Inventory Level: 99.22
# Total Cost per Year: 1711.28
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 49 - EOQ Results:
# Optimal Order Quantity (Q): 164.43
# Number of Orders per Year: 6.29
# Time Between Orders (Months): 1.91
# Cycle Service Level: nan%
# Average Inventory Level: 82.22
# Total Cost per Year: 1920.02
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 50 - EOQ Results:
# Optimal Order Quantity (Q): 147.36
# Number of Orders per Year: 5.59
# Time Between Orders (Months): 2.15
# Cycle Service Level: nan%
# Average Inventory Level: 73.68
# Total Cost per Year: 1706.41
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 51 - EOQ Results:
# Optimal Order Quantity (Q): 181.77
# Number of Orders per Year: 5.68
# Time Between Orders (Months): 2.11
# Cycle Service Level: nan%
# Average Inventory Level: 90.88
# Total Cost per Year: 1740.31
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 52 - EOQ Results:
# Optimal Order Quantity (Q): 166.57
# Number of Orders per Year: 5.77
# Time Between Orders (Months): 2.08
# Cycle Service Level: nan%
# Average Inventory Level: 83.29
# Total Cost per Year: 1764.97
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 53 - EOQ Results:
# Optimal Order Quantity (Q): 163.26
# Number of Orders per Year: 5.71
# Time Between Orders (Months): 2.10
# Cycle Service Level: nan%
# Average Inventory Level: 81.63
# Total Cost per Year: 1745.86
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 54 - EOQ Results:
# Optimal Order Quantity (Q): 176.14
# Number of Orders per Year: 6.02
# Time Between Orders (Months): 1.99
# Cycle Service Level: nan%
# Average Inventory Level: 88.07
# Total Cost per Year: 1842.57
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 55 - EOQ Results:
# Optimal Order Quantity (Q): 187.14
# Number of Orders per Year: 5.89
# Time Between Orders (Months): 2.04
# Cycle Service Level: nan%
# Average Inventory Level: 93.57
# Total Cost per Year: 1805.81
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 56 - EOQ Results:
# Optimal Order Quantity (Q): 187.50
# Number of Orders per Year: 5.83
# Time Between Orders (Months): 2.06
# Cycle Service Level: nan%
# Average Inventory Level: 93.75
# Total Cost per Year: 1786.54
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 57 - EOQ Results:
# Optimal Order Quantity (Q): 165.99
# Number of Orders per Year: 5.52
# Time Between Orders (Months): 2.17
# Cycle Service Level: nan%
# Average Inventory Level: 83.00
# Total Cost per Year: 1688.86
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 58 - EOQ Results:
# Optimal Order Quantity (Q): 161.31
# Number of Orders per Year: 6.01
# Time Between Orders (Months): 2.00
# Cycle Service Level: nan%
# Average Inventory Level: 80.65
# Total Cost per Year: 1834.53
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 59 - EOQ Results:
# Optimal Order Quantity (Q): 171.45
# Number of Orders per Year: 6.03
# Time Between Orders (Months): 1.99
# Cycle Service Level: nan%
# Average Inventory Level: 85.73
# Total Cost per Year: 1842.01
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 60 - EOQ Results:
# Optimal Order Quantity (Q): 184.92
# Number of Orders per Year: 5.94
# Time Between Orders (Months): 2.02
# Cycle Service Level: nan%
# Average Inventory Level: 92.46
# Total Cost per Year: 1817.61
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 61 - EOQ Results:
# Optimal Order Quantity (Q): 162.84
# Number of Orders per Year: 5.85
# Time Between Orders (Months): 2.05
# Cycle Service Level: nan%
# Average Inventory Level: 81.42
# Total Cost per Year: 1786.61
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 62 - EOQ Results:
# Optimal Order Quantity (Q): 202.91
# Number of Orders per Year: 4.84
# Time Between Orders (Months): 2.48
# Cycle Service Level: nan%
# Average Inventory Level: 101.45
# Total Cost per Year: 1491.65
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 63 - EOQ Results:
# Optimal Order Quantity (Q): 154.70
# Number of Orders per Year: 5.75
# Time Between Orders (Months): 2.09
# Cycle Service Level: nan%
# Average Inventory Level: 77.35
# Total Cost per Year: 1755.64
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 64 - EOQ Results:
# Optimal Order Quantity (Q): 178.81
# Number of Orders per Year: 4.92
# Time Between Orders (Months): 2.44
# Cycle Service Level: nan%
# Average Inventory Level: 89.41
# Total Cost per Year: 1512.81
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 65 - EOQ Results:
# Optimal Order Quantity (Q): 183.46
# Number of Orders per Year: 5.89
# Time Between Orders (Months): 2.04
# Cycle Service Level: nan%
# Average Inventory Level: 91.73
# Total Cost per Year: 1804.80
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 66 - EOQ Results:
# Optimal Order Quantity (Q): 195.87
# Number of Orders per Year: 5.80
# Time Between Orders (Months): 2.07
# Cycle Service Level: nan%
# Average Inventory Level: 97.93
# Total Cost per Year: 1778.55
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 67 - EOQ Results:
# Optimal Order Quantity (Q): 184.97
# Number of Orders per Year: 5.37
# Time Between Orders (Months): 2.24
# Cycle Service Level: nan%
# Average Inventory Level: 92.48
# Total Cost per Year: 1647.21
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 68 - EOQ Results:
# Optimal Order Quantity (Q): 171.98
# Number of Orders per Year: 6.40
# Time Between Orders (Months): 1.88
# Cycle Service Level: nan%
# Average Inventory Level: 85.99
# Total Cost per Year: 1953.84
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 69 - EOQ Results:
# Optimal Order Quantity (Q): 180.58
# Number of Orders per Year: 5.74
# Time Between Orders (Months): 2.09
# Cycle Service Level: nan%
# Average Inventory Level: 90.29
# Total Cost per Year: 1757.48
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 70 - EOQ Results:
# Optimal Order Quantity (Q): 164.70
# Number of Orders per Year: 5.68
# Time Between Orders (Months): 2.11
# Cycle Service Level: nan%
# Average Inventory Level: 82.35
# Total Cost per Year: 1736.97
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 71 - EOQ Results:
# Optimal Order Quantity (Q): 176.72
# Number of Orders per Year: 5.86
# Time Between Orders (Months): 2.05
# Cycle Service Level: nan%
# Average Inventory Level: 88.36
# Total Cost per Year: 1794.27
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 72 - EOQ Results:
# Optimal Order Quantity (Q): 181.76
# Number of Orders per Year: 6.35
# Time Between Orders (Months): 1.89
# Cycle Service Level: nan%
# Average Inventory Level: 90.88
# Total Cost per Year: 1940.70
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 73 - EOQ Results:
# Optimal Order Quantity (Q): 172.23
# Number of Orders per Year: 5.79
# Time Between Orders (Months): 2.07
# Cycle Service Level: nan%
# Average Inventory Level: 86.12
# Total Cost per Year: 1770.02
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 74 - EOQ Results:
# Optimal Order Quantity (Q): 199.50
# Number of Orders per Year: 5.80
# Time Between Orders (Months): 2.07
# Cycle Service Level: nan%
# Average Inventory Level: 99.75
# Total Cost per Year: 1778.94
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 75 - EOQ Results:
# Optimal Order Quantity (Q): 141.90
# Number of Orders per Year: 5.20
# Time Between Orders (Months): 2.31
# Cycle Service Level: nan%
# Average Inventory Level: 70.95
# Total Cost per Year: 1588.72
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 76 - EOQ Results:
# Optimal Order Quantity (Q): 184.80
# Number of Orders per Year: 5.86
# Time Between Orders (Months): 2.05
# Cycle Service Level: nan%
# Average Inventory Level: 92.40
# Total Cost per Year: 1793.74
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 77 - EOQ Results:
# Optimal Order Quantity (Q): 189.31
# Number of Orders per Year: 5.33
# Time Between Orders (Months): 2.25
# Cycle Service Level: nan%
# Average Inventory Level: 94.66
# Total Cost per Year: 1636.32
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 78 - EOQ Results:
# Optimal Order Quantity (Q): 174.37
# Number of Orders per Year: 5.56
# Time Between Orders (Months): 2.16
# Cycle Service Level: nan%
# Average Inventory Level: 87.18
# Total Cost per Year: 1703.92
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 79 - EOQ Results:
# Optimal Order Quantity (Q): 162.25
# Number of Orders per Year: 6.22
# Time Between Orders (Months): 1.93
# Cycle Service Level: nan%
# Average Inventory Level: 81.12
# Total Cost per Year: 1898.43
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 80 - EOQ Results:
# Optimal Order Quantity (Q): 148.84
# Number of Orders per Year: 5.38
# Time Between Orders (Months): 2.23
# Cycle Service Level: nan%
# Average Inventory Level: 74.42
# Total Cost per Year: 1644.73
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 81 - EOQ Results:
# Optimal Order Quantity (Q): 174.36
# Number of Orders per Year: 5.61
# Time Between Orders (Months): 2.14
# Cycle Service Level: nan%
# Average Inventory Level: 87.18
# Total Cost per Year: 1717.67
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 82 - EOQ Results:
# Optimal Order Quantity (Q): 179.43
# Number of Orders per Year: 5.77
# Time Between Orders (Months): 2.08
# Cycle Service Level: nan%
# Average Inventory Level: 89.72
# Total Cost per Year: 1767.54
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 83 - EOQ Results:
# Optimal Order Quantity (Q): 188.62
# Number of Orders per Year: 6.09
# Time Between Orders (Months): 1.97
# Cycle Service Level: nan%
# Average Inventory Level: 94.31
# Total Cost per Year: 1863.27
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 84 - EOQ Results:
# Optimal Order Quantity (Q): 153.47
# Number of Orders per Year: 6.18
# Time Between Orders (Months): 1.94
# Cycle Service Level: nan%
# Average Inventory Level: 76.74
# Total Cost per Year: 1884.14
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 85 - EOQ Results:
# Optimal Order Quantity (Q): 162.97
# Number of Orders per Year: 5.64
# Time Between Orders (Months): 2.13
# Cycle Service Level: nan%
# Average Inventory Level: 81.49
# Total Cost per Year: 1724.57
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 86 - EOQ Results:
# Optimal Order Quantity (Q): 165.29
# Number of Orders per Year: 5.75
# Time Between Orders (Months): 2.09
# Cycle Service Level: nan%
# Average Inventory Level: 82.64
# Total Cost per Year: 1757.01
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 87 - EOQ Results:
# Optimal Order Quantity (Q): 172.30
# Number of Orders per Year: 6.34
# Time Between Orders (Months): 1.89
# Cycle Service Level: nan%
# Average Inventory Level: 86.15
# Total Cost per Year: 1934.99
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 88 - EOQ Results:
# Optimal Order Quantity (Q): 173.96
# Number of Orders per Year: 5.94
# Time Between Orders (Months): 2.02
# Cycle Service Level: nan%
# Average Inventory Level: 86.98
# Total Cost per Year: 1815.98
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 89 - EOQ Results:
# Optimal Order Quantity (Q): 170.78
# Number of Orders per Year: 5.55
# Time Between Orders (Months): 2.16
# Cycle Service Level: nan%
# Average Inventory Level: 85.39
# Total Cost per Year: 1697.73
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 90 - EOQ Results:
# Optimal Order Quantity (Q): 179.36
# Number of Orders per Year: 5.86
# Time Between Orders (Months): 2.05
# Cycle Service Level: nan%
# Average Inventory Level: 89.68
# Total Cost per Year: 1794.30
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 91 - EOQ Results:
# Optimal Order Quantity (Q): 174.67
# Number of Orders per Year: 5.78
# Time Between Orders (Months): 2.08
# Cycle Service Level: nan%
# Average Inventory Level: 87.34
# Total Cost per Year: 1769.13
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 92 - EOQ Results:
# Optimal Order Quantity (Q): 181.74
# Number of Orders per Year: 6.04
# Time Between Orders (Months): 1.99
# Cycle Service Level: nan%
# Average Inventory Level: 90.87
# Total Cost per Year: 1846.97
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 93 - EOQ Results:
# Optimal Order Quantity (Q): 161.25
# Number of Orders per Year: 5.77
# Time Between Orders (Months): 2.08
# Cycle Service Level: nan%
# Average Inventory Level: 80.63
# Total Cost per Year: 1762.09
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 94 - EOQ Results:
# Optimal Order Quantity (Q): 169.90
# Number of Orders per Year: 5.69
# Time Between Orders (Months): 2.11
# Cycle Service Level: nan%
# Average Inventory Level: 84.95
# Total Cost per Year: 1741.84
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 95 - EOQ Results:
# Optimal Order Quantity (Q): 163.88
# Number of Orders per Year: 5.86
# Time Between Orders (Months): 2.05
# Cycle Service Level: nan%
# Average Inventory Level: 81.94
# Total Cost per Year: 1791.62
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 96 - EOQ Results:
# Optimal Order Quantity (Q): 160.68
# Number of Orders per Year: 5.31
# Time Between Orders (Months): 2.26
# Cycle Service Level: nan%
# Average Inventory Level: 80.34
# Total Cost per Year: 1625.96
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 97 - EOQ Results:
# Optimal Order Quantity (Q): 175.06
# Number of Orders per Year: 5.88
# Time Between Orders (Months): 2.04
# Cycle Service Level: nan%
# Average Inventory Level: 87.53
# Total Cost per Year: 1799.42
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 98 - EOQ Results:
# Optimal Order Quantity (Q): 196.14
# Number of Orders per Year: 5.23
# Time Between Orders (Months): 2.29
# Cycle Service Level: nan%
# Average Inventory Level: 98.07
# Total Cost per Year: 1608.69
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 99 - EOQ Results:
# Optimal Order Quantity (Q): 165.82
# Number of Orders per Year: 6.03
# Time Between Orders (Months): 1.99
# Cycle Service Level: nan%
# Average Inventory Level: 82.91
# Total Cost per Year: 1843.29
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 100 - EOQ Results:
# Optimal Order Quantity (Q): 168.27
# Number of Orders per Year: 5.80
# Time Between Orders (Months): 2.07
# Cycle Service Level: nan%
# Average Inventory Level: 84.14
# Total Cost per Year: 1774.67
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 101 - EOQ Results:
# Optimal Order Quantity (Q): 153.03
# Number of Orders per Year: 5.61
# Time Between Orders (Months): 2.14
# Cycle Service Level: nan%
# Average Inventory Level: 76.51
# Total Cost per Year: 1713.58
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 102 - EOQ Results:
# Optimal Order Quantity (Q): 201.13
# Number of Orders per Year: 4.76
# Time Between Orders (Months): 2.52
# Cycle Service Level: nan%
# Average Inventory Level: 100.57
# Total Cost per Year: 1469.03
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 103 - EOQ Results:
# Optimal Order Quantity (Q): 154.81
# Number of Orders per Year: 6.24
# Time Between Orders (Months): 1.92
# Cycle Service Level: nan%
# Average Inventory Level: 77.41
# Total Cost per Year: 1902.39
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 104 - EOQ Results:
# Optimal Order Quantity (Q): 167.28
# Number of Orders per Year: 5.50
# Time Between Orders (Months): 2.18
# Cycle Service Level: nan%
# Average Inventory Level: 83.64
# Total Cost per Year: 1682.94
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 105 - EOQ Results:
# Optimal Order Quantity (Q): 163.01
# Number of Orders per Year: 6.04
# Time Between Orders (Months): 1.99
# Cycle Service Level: nan%
# Average Inventory Level: 81.50
# Total Cost per Year: 1843.32
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 106 - EOQ Results:
# Optimal Order Quantity (Q): 186.64
# Number of Orders per Year: 5.57
# Time Between Orders (Months): 2.15
# Cycle Service Level: nan%
# Average Inventory Level: 93.32
# Total Cost per Year: 1709.64
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 107 - EOQ Results:
# Optimal Order Quantity (Q): 183.30
# Number of Orders per Year: 6.48
# Time Between Orders (Months): 1.85
# Cycle Service Level: nan%
# Average Inventory Level: 91.65
# Total Cost per Year: 1982.00
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 108 - EOQ Results:
# Optimal Order Quantity (Q): 184.71
# Number of Orders per Year: 5.51
# Time Between Orders (Months): 2.18
# Cycle Service Level: nan%
# Average Inventory Level: 92.35
# Total Cost per Year: 1689.46
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 109 - EOQ Results:
# Optimal Order Quantity (Q): 181.16
# Number of Orders per Year: 5.66
# Time Between Orders (Months): 2.12
# Cycle Service Level: nan%
# Average Inventory Level: 90.58
# Total Cost per Year: 1734.85
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 110 - EOQ Results:
# Optimal Order Quantity (Q): 158.09
# Number of Orders per Year: 6.28
# Time Between Orders (Months): 1.91
# Cycle Service Level: nan%
# Average Inventory Level: 79.05
# Total Cost per Year: 1915.13
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 111 - EOQ Results:
# Optimal Order Quantity (Q): 157.21
# Number of Orders per Year: 5.14
# Time Between Orders (Months): 2.33
# Cycle Service Level: nan%
# Average Inventory Level: 78.60
# Total Cost per Year: 1573.56
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 112 - EOQ Results:
# Optimal Order Quantity (Q): 171.12
# Number of Orders per Year: 5.83
# Time Between Orders (Months): 2.06
# Cycle Service Level: nan%
# Average Inventory Level: 85.56
# Total Cost per Year: 1782.68
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 113 - EOQ Results:
# Optimal Order Quantity (Q): 166.63
# Number of Orders per Year: 6.04
# Time Between Orders (Months): 1.99
# Cycle Service Level: nan%
# Average Inventory Level: 83.31
# Total Cost per Year: 1844.59
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 114 - EOQ Results:
# Optimal Order Quantity (Q): 188.74
# Number of Orders per Year: 6.60
# Time Between Orders (Months): 1.82
# Cycle Service Level: nan%
# Average Inventory Level: 94.37
# Total Cost per Year: 2018.73
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 115 - EOQ Results:
# Optimal Order Quantity (Q): 170.26
# Number of Orders per Year: 5.76
# Time Between Orders (Months): 2.08
# Cycle Service Level: nan%
# Average Inventory Level: 85.13
# Total Cost per Year: 1762.21
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 116 - EOQ Results:
# Optimal Order Quantity (Q): 172.67
# Number of Orders per Year: 5.97
# Time Between Orders (Months): 2.01
# Cycle Service Level: nan%
# Average Inventory Level: 86.34
# Total Cost per Year: 1824.30
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 117 - EOQ Results:
# Optimal Order Quantity (Q): 155.25
# Number of Orders per Year: 6.42
# Time Between Orders (Months): 1.87
# Cycle Service Level: nan%
# Average Inventory Level: 77.63
# Total Cost per Year: 1956.70
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 118 - EOQ Results:
# Optimal Order Quantity (Q): 163.24
# Number of Orders per Year: 5.41
# Time Between Orders (Months): 2.22
# Cycle Service Level: nan%
# Average Inventory Level: 81.62
# Total Cost per Year: 1655.65
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 119 - EOQ Results:
# Optimal Order Quantity (Q): 181.02
# Number of Orders per Year: 6.16
# Time Between Orders (Months): 1.95
# Cycle Service Level: nan%
# Average Inventory Level: 90.51
# Total Cost per Year: 1882.84
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 120 - EOQ Results:
# Optimal Order Quantity (Q): 170.85
# Number of Orders per Year: 6.29
# Time Between Orders (Months): 1.91
# Cycle Service Level: nan%
# Average Inventory Level: 85.42
# Total Cost per Year: 1922.15
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 121 - EOQ Results:
# Optimal Order Quantity (Q): 170.73
# Number of Orders per Year: 6.32
# Time Between Orders (Months): 1.90
# Cycle Service Level: nan%
# Average Inventory Level: 85.37
# Total Cost per Year: 1930.25
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 122 - EOQ Results:
# Optimal Order Quantity (Q): 156.13
# Number of Orders per Year: 5.82
# Time Between Orders (Months): 2.06
# Cycle Service Level: nan%
# Average Inventory Level: 78.07
# Total Cost per Year: 1777.91
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 123 - EOQ Results:
# Optimal Order Quantity (Q): 179.32
# Number of Orders per Year: 6.36
# Time Between Orders (Months): 1.89
# Cycle Service Level: nan%
# Average Inventory Level: 89.66
# Total Cost per Year: 1943.57
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 124 - EOQ Results:
# Optimal Order Quantity (Q): 170.66
# Number of Orders per Year: 5.04
# Time Between Orders (Months): 2.38
# Cycle Service Level: nan%
# Average Inventory Level: 85.33
# Total Cost per Year: 1545.62
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 125 - EOQ Results:
# Optimal Order Quantity (Q): 165.23
# Number of Orders per Year: 6.41
# Time Between Orders (Months): 1.87
# Cycle Service Level: nan%
# Average Inventory Level: 82.62
# Total Cost per Year: 1955.24
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 126 - EOQ Results:
# Optimal Order Quantity (Q): 203.24
# Number of Orders per Year: 6.00
# Time Between Orders (Months): 2.00
# Cycle Service Level: nan%
# Average Inventory Level: 101.62
# Total Cost per Year: 1840.07
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 127 - EOQ Results:
# Optimal Order Quantity (Q): 161.97
# Number of Orders per Year: 5.56
# Time Between Orders (Months): 2.16
# Cycle Service Level: nan%
# Average Inventory Level: 80.99
# Total Cost per Year: 1701.12
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 128 - EOQ Results:
# Optimal Order Quantity (Q): 174.96
# Number of Orders per Year: 5.39
# Time Between Orders (Months): 2.23
# Cycle Service Level: nan%
# Average Inventory Level: 87.48
# Total Cost per Year: 1652.60
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 129 - EOQ Results:
# Optimal Order Quantity (Q): 174.63
# Number of Orders per Year: 5.78
# Time Between Orders (Months): 2.07
# Cycle Service Level: nan%
# Average Inventory Level: 87.31
# Total Cost per Year: 1769.99
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 130 - EOQ Results:
# Optimal Order Quantity (Q): 166.08
# Number of Orders per Year: 5.72
# Time Between Orders (Months): 2.10
# Cycle Service Level: nan%
# Average Inventory Level: 83.04
# Total Cost per Year: 1748.62
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 131 - EOQ Results:
# Optimal Order Quantity (Q): 156.71
# Number of Orders per Year: 5.39
# Time Between Orders (Months): 2.23
# Cycle Service Level: nan%
# Average Inventory Level: 78.36
# Total Cost per Year: 1648.83
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 132 - EOQ Results:
# Optimal Order Quantity (Q): 170.24
# Number of Orders per Year: 5.91
# Time Between Orders (Months): 2.03
# Cycle Service Level: nan%
# Average Inventory Level: 85.12
# Total Cost per Year: 1808.31
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 133 - EOQ Results:
# Optimal Order Quantity (Q): 151.95
# Number of Orders per Year: 5.88
# Time Between Orders (Months): 2.04
# Cycle Service Level: nan%
# Average Inventory Level: 75.97
# Total Cost per Year: 1795.04
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 134 - EOQ Results:
# Optimal Order Quantity (Q): 173.37
# Number of Orders per Year: 6.04
# Time Between Orders (Months): 1.99
# Cycle Service Level: nan%
# Average Inventory Level: 86.69
# Total Cost per Year: 1847.02
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 135 - EOQ Results:
# Optimal Order Quantity (Q): 167.10
# Number of Orders per Year: 5.43
# Time Between Orders (Months): 2.21
# Cycle Service Level: nan%
# Average Inventory Level: 83.55
# Total Cost per Year: 1663.65
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 136 - EOQ Results:
# Optimal Order Quantity (Q): 177.77
# Number of Orders per Year: 6.50
# Time Between Orders (Months): 1.85
# Cycle Service Level: nan%
# Average Inventory Level: 88.89
# Total Cost per Year: 1984.67
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 137 - EOQ Results:
# Optimal Order Quantity (Q): 157.20
# Number of Orders per Year: 5.86
# Time Between Orders (Months): 2.05
# Cycle Service Level: nan%
# Average Inventory Level: 78.60
# Total Cost per Year: 1790.39
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 138 - EOQ Results:
# Optimal Order Quantity (Q): 181.93
# Number of Orders per Year: 5.32
# Time Between Orders (Months): 2.26
# Cycle Service Level: nan%
# Average Inventory Level: 90.96
# Total Cost per Year: 1632.30
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 139 - EOQ Results:
# Optimal Order Quantity (Q): 174.96
# Number of Orders per Year: 6.18
# Time Between Orders (Months): 1.94
# Cycle Service Level: nan%
# Average Inventory Level: 87.48
# Total Cost per Year: 1889.14
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 140 - EOQ Results:
# Optimal Order Quantity (Q): 156.79
# Number of Orders per Year: 5.59
# Time Between Orders (Months): 2.15
# Cycle Service Level: nan%
# Average Inventory Level: 78.40
# Total Cost per Year: 1709.21
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 141 - EOQ Results:
# Optimal Order Quantity (Q): 177.83
# Number of Orders per Year: 5.75
# Time Between Orders (Months): 2.09
# Cycle Service Level: nan%
# Average Inventory Level: 88.91
# Total Cost per Year: 1760.95
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 142 - EOQ Results:
# Optimal Order Quantity (Q): 172.68
# Number of Orders per Year: 6.55
# Time Between Orders (Months): 1.83
# Cycle Service Level: nan%
# Average Inventory Level: 86.34
# Total Cost per Year: 1998.92
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 143 - EOQ Results:
# Optimal Order Quantity (Q): 159.88
# Number of Orders per Year: 5.25
# Time Between Orders (Months): 2.29
# Cycle Service Level: nan%
# Average Inventory Level: 79.94
# Total Cost per Year: 1606.77
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 144 - EOQ Results:
# Optimal Order Quantity (Q): 173.71
# Number of Orders per Year: 5.86
# Time Between Orders (Months): 2.05
# Cycle Service Level: nan%
# Average Inventory Level: 86.85
# Total Cost per Year: 1793.65
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 145 - EOQ Results:
# Optimal Order Quantity (Q): 176.98
# Number of Orders per Year: 5.80
# Time Between Orders (Months): 2.07
# Cycle Service Level: nan%
# Average Inventory Level: 88.49
# Total Cost per Year: 1774.56
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 146 - EOQ Results:
# Optimal Order Quantity (Q): 179.71
# Number of Orders per Year: 6.00
# Time Between Orders (Months): 2.00
# Cycle Service Level: nan%
# Average Inventory Level: 89.85
# Total Cost per Year: 1835.83
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 147 - EOQ Results:
# Optimal Order Quantity (Q): 171.83
# Number of Orders per Year: 5.10
# Time Between Orders (Months): 2.35
# Cycle Service Level: nan%
# Average Inventory Level: 85.92
# Total Cost per Year: 1564.31
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 148 - EOQ Results:
# Optimal Order Quantity (Q): 174.41
# Number of Orders per Year: 4.98
# Time Between Orders (Months): 2.41
# Cycle Service Level: nan%
# Average Inventory Level: 87.21
# Total Cost per Year: 1527.83
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 149 - EOQ Results:
# Optimal Order Quantity (Q): 165.00
# Number of Orders per Year: 6.38
# Time Between Orders (Months): 1.88
# Cycle Service Level: nan%
# Average Inventory Level: 82.50
# Total Cost per Year: 1946.09
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 150 - EOQ Results:
# Optimal Order Quantity (Q): 183.71
# Number of Orders per Year: 5.61
# Time Between Orders (Months): 2.14
# Cycle Service Level: nan%
# Average Inventory Level: 91.86
# Total Cost per Year: 1718.25
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 151 - EOQ Results:
# Optimal Order Quantity (Q): 184.76
# Number of Orders per Year: 5.55
# Time Between Orders (Months): 2.16
# Cycle Service Level: nan%
# Average Inventory Level: 92.38
# Total Cost per Year: 1701.37
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 152 - EOQ Results:
# Optimal Order Quantity (Q): 198.89
# Number of Orders per Year: 5.20
# Time Between Orders (Months): 2.31
# Cycle Service Level: nan%
# Average Inventory Level: 99.45
# Total Cost per Year: 1600.40
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 153 - EOQ Results:
# Optimal Order Quantity (Q): 172.82
# Number of Orders per Year: 5.39
# Time Between Orders (Months): 2.23
# Cycle Service Level: nan%
# Average Inventory Level: 86.41
# Total Cost per Year: 1652.38
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 154 - EOQ Results:
# Optimal Order Quantity (Q): 188.09
# Number of Orders per Year: 5.44
# Time Between Orders (Months): 2.21
# Cycle Service Level: nan%
# Average Inventory Level: 94.04
# Total Cost per Year: 1669.65
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 155 - EOQ Results:
# Optimal Order Quantity (Q): 162.86
# Number of Orders per Year: 6.32
# Time Between Orders (Months): 1.90
# Cycle Service Level: nan%
# Average Inventory Level: 81.43
# Total Cost per Year: 1928.61
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 156 - EOQ Results:
# Optimal Order Quantity (Q): 159.07
# Number of Orders per Year: 5.84
# Time Between Orders (Months): 2.06
# Cycle Service Level: nan%
# Average Inventory Level: 79.53
# Total Cost per Year: 1783.10
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 157 - EOQ Results:
# Optimal Order Quantity (Q): 195.52
# Number of Orders per Year: 6.07
# Time Between Orders (Months): 1.98
# Cycle Service Level: nan%
# Average Inventory Level: 97.76
# Total Cost per Year: 1859.75
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 158 - EOQ Results:
# Optimal Order Quantity (Q): 160.14
# Number of Orders per Year: 6.54
# Time Between Orders (Months): 1.83
# Cycle Service Level: nan%
# Average Inventory Level: 80.07
# Total Cost per Year: 1994.14
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 159 - EOQ Results:
# Optimal Order Quantity (Q): 155.12
# Number of Orders per Year: 5.68
# Time Between Orders (Months): 2.11
# Cycle Service Level: nan%
# Average Inventory Level: 77.56
# Total Cost per Year: 1734.57
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 160 - EOQ Results:
# Optimal Order Quantity (Q): 181.78
# Number of Orders per Year: 5.86
# Time Between Orders (Months): 2.05
# Cycle Service Level: nan%
# Average Inventory Level: 90.89
# Total Cost per Year: 1795.08
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 161 - EOQ Results:
# Optimal Order Quantity (Q): 190.00
# Number of Orders per Year: 4.75
# Time Between Orders (Months): 2.53
# Cycle Service Level: nan%
# Average Inventory Level: 95.00
# Total Cost per Year: 1463.08
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 162 - EOQ Results:
# Optimal Order Quantity (Q): 162.26
# Number of Orders per Year: 6.65
# Time Between Orders (Months): 1.81
# Cycle Service Level: nan%
# Average Inventory Level: 81.13
# Total Cost per Year: 2026.82
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 163 - EOQ Results:
# Optimal Order Quantity (Q): 197.18
# Number of Orders per Year: 5.66
# Time Between Orders (Months): 2.12
# Cycle Service Level: nan%
# Average Inventory Level: 98.59
# Total Cost per Year: 1737.20
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 164 - EOQ Results:
# Optimal Order Quantity (Q): 181.55
# Number of Orders per Year: 5.06
# Time Between Orders (Months): 2.37
# Cycle Service Level: nan%
# Average Inventory Level: 90.78
# Total Cost per Year: 1553.11
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 165 - EOQ Results:
# Optimal Order Quantity (Q): 172.74
# Number of Orders per Year: 6.35
# Time Between Orders (Months): 1.89
# Cycle Service Level: nan%
# Average Inventory Level: 86.37
# Total Cost per Year: 1938.58
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 166 - EOQ Results:
# Optimal Order Quantity (Q): 158.47
# ...
# Optimal Order Quantity (Q): 166.79
# Number of Orders per Year: 5.35
# Time Between Orders (Months): 2.24
# Cycle Service Level: nan%
# Average Inventory Level: 83.39
# Total Cost per Year: 1639.58
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 947 - EOQ Results:
# Optimal Order Quantity (Q): 156.52
# Number of Orders per Year: 5.41
# Time Between Orders (Months): 2.22
# Cycle Service Level: nan%
# Average Inventory Level: 78.26
# Total Cost per Year: 1655.56
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 948 - EOQ Results:
# Optimal Order Quantity (Q): 167.35
# Number of Orders per Year: 5.56
# Time Between Orders (Months): 2.16
# Cycle Service Level: nan%
# Average Inventory Level: 83.68
# Total Cost per Year: 1702.08
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 949 - EOQ Results:
# Optimal Order Quantity (Q): 163.83
# Number of Orders per Year: 6.08
# Time Between Orders (Months): 1.97
# Cycle Service Level: nan%
# Average Inventory Level: 81.92
# Total Cost per Year: 1855.57
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 950 - EOQ Results:
# Optimal Order Quantity (Q): 175.75
# Number of Orders per Year: 5.83
# Time Between Orders (Months): 2.06
# Cycle Service Level: nan%
# Average Inventory Level: 87.88
# Total Cost per Year: 1783.64
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 951 - EOQ Results:
# Optimal Order Quantity (Q): 188.64
# Number of Orders per Year: 5.17
# Time Between Orders (Months): 2.32
# Cycle Service Level: nan%
# Average Inventory Level: 94.32
# Total Cost per Year: 1589.68
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 952 - EOQ Results:
# Optimal Order Quantity (Q): 166.06
# Number of Orders per Year: 6.23
# Time Between Orders (Months): 1.92
# Cycle Service Level: nan%
# Average Inventory Level: 83.03
# Total Cost per Year: 1903.38
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 953 - EOQ Results:
# Optimal Order Quantity (Q): 169.88
# Number of Orders per Year: 5.15
# Time Between Orders (Months): 2.33
# Cycle Service Level: nan%
# Average Inventory Level: 84.94
# Total Cost per Year: 1578.91
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 954 - EOQ Results:
# Optimal Order Quantity (Q): 191.66
# Number of Orders per Year: 5.97
# Time Between Orders (Months): 2.01
# Cycle Service Level: nan%
# Average Inventory Level: 95.83
# Total Cost per Year: 1829.61
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 955 - EOQ Results:
# Optimal Order Quantity (Q): 177.87
# Number of Orders per Year: 5.58
# Time Between Orders (Months): 2.15
# Cycle Service Level: nan%
# Average Inventory Level: 88.94
# Total Cost per Year: 1708.33
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 956 - EOQ Results:
# Optimal Order Quantity (Q): 171.24
# Number of Orders per Year: 6.49
# Time Between Orders (Months): 1.85
# Cycle Service Level: nan%
# Average Inventory Level: 85.62
# Total Cost per Year: 1981.96
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 957 - EOQ Results:
# Optimal Order Quantity (Q): 198.63
# Number of Orders per Year: 5.21
# Time Between Orders (Months): 2.30
# Cycle Service Level: nan%
# Average Inventory Level: 99.32
# Total Cost per Year: 1601.83
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 958 - EOQ Results:
# Optimal Order Quantity (Q): 154.52
# Number of Orders per Year: 6.77
# Time Between Orders (Months): 1.77
# Cycle Service Level: nan%
# Average Inventory Level: 77.26
# Total Cost per Year: 2061.01
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 959 - EOQ Results:
# Optimal Order Quantity (Q): 169.35
# Number of Orders per Year: 6.24
# Time Between Orders (Months): 1.92
# Cycle Service Level: nan%
# Average Inventory Level: 84.68
# Total Cost per Year: 1906.25
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 960 - EOQ Results:
# Optimal Order Quantity (Q): 175.10
# Number of Orders per Year: 5.97
# Time Between Orders (Months): 2.01
# Cycle Service Level: nan%
# Average Inventory Level: 87.55
# Total Cost per Year: 1825.07
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 961 - EOQ Results:
# Optimal Order Quantity (Q): 179.18
# Number of Orders per Year: 5.94
# Time Between Orders (Months): 2.02
# Cycle Service Level: nan%
# Average Inventory Level: 89.59
# Total Cost per Year: 1817.77
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 962 - EOQ Results:
# Optimal Order Quantity (Q): 181.78
# Number of Orders per Year: 6.23
# Time Between Orders (Months): 1.93
# Cycle Service Level: nan%
# Average Inventory Level: 90.89
# Total Cost per Year: 1906.06
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 963 - EOQ Results:
# Optimal Order Quantity (Q): 170.51
# Number of Orders per Year: 5.98
# Time Between Orders (Months): 2.01
# Cycle Service Level: nan%
# Average Inventory Level: 85.26
# Total Cost per Year: 1828.08
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 964 - EOQ Results:
# Optimal Order Quantity (Q): 173.72
# Number of Orders per Year: 6.16
# Time Between Orders (Months): 1.95
# Cycle Service Level: nan%
# Average Inventory Level: 86.86
# Total Cost per Year: 1884.07
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 965 - EOQ Results:
# Optimal Order Quantity (Q): 167.83
# Number of Orders per Year: 5.91
# Time Between Orders (Months): 2.03
# Cycle Service Level: nan%
# Average Inventory Level: 83.91
# Total Cost per Year: 1805.08
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 966 - EOQ Results:
# Optimal Order Quantity (Q): 184.43
# Number of Orders per Year: 6.20
# Time Between Orders (Months): 1.93
# Cycle Service Level: nan%
# Average Inventory Level: 92.22
# Total Cost per Year: 1897.74
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 967 - EOQ Results:
# Optimal Order Quantity (Q): 168.92
# Number of Orders per Year: 5.52
# Time Between Orders (Months): 2.17
# Cycle Service Level: nan%
# Average Inventory Level: 84.46
# Total Cost per Year: 1689.65
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 968 - EOQ Results:
# Optimal Order Quantity (Q): 189.60
# Number of Orders per Year: 6.22
# Time Between Orders (Months): 1.93
# Cycle Service Level: nan%
# Average Inventory Level: 94.80
# Total Cost per Year: 1905.20
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 969 - EOQ Results:
# Optimal Order Quantity (Q): 174.57
# Number of Orders per Year: 5.71
# Time Between Orders (Months): 2.10
# Cycle Service Level: nan%
# Average Inventory Level: 87.28
# Total Cost per Year: 1746.55
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 970 - EOQ Results:
# Optimal Order Quantity (Q): 151.95
# Number of Orders per Year: 5.64
# Time Between Orders (Months): 2.13
# Cycle Service Level: nan%
# Average Inventory Level: 75.98
# Total Cost per Year: 1722.20
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 971 - EOQ Results:
# Optimal Order Quantity (Q): 169.36
# Number of Orders per Year: 5.98
# Time Between Orders (Months): 2.01
# Cycle Service Level: nan%
# Average Inventory Level: 84.68
# Total Cost per Year: 1827.97
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 972 - EOQ Results:
# Optimal Order Quantity (Q): 199.00
# Number of Orders per Year: 4.68
# Time Between Orders (Months): 2.56
# Cycle Service Level: nan%
# Average Inventory Level: 99.50
# Total Cost per Year: 1444.66
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 973 - EOQ Results:
# Optimal Order Quantity (Q): 174.70
# Number of Orders per Year: 6.21
# Time Between Orders (Months): 1.93
# Cycle Service Level: nan%
# Average Inventory Level: 87.35
# Total Cost per Year: 1896.53
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 974 - EOQ Results:
# Optimal Order Quantity (Q): 165.85
# Number of Orders per Year: 5.64
# Time Between Orders (Months): 2.13
# Cycle Service Level: nan%
# Average Inventory Level: 82.93
# Total Cost per Year: 1723.97
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 975 - EOQ Results:
# Optimal Order Quantity (Q): 169.46
# Number of Orders per Year: 5.64
# Time Between Orders (Months): 2.13
# Cycle Service Level: nan%
# Average Inventory Level: 84.73
# Total Cost per Year: 1725.28
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 976 - EOQ Results:
# Optimal Order Quantity (Q): 159.11
# Number of Orders per Year: 5.10
# Time Between Orders (Months): 2.35
# Cycle Service Level: nan%
# Average Inventory Level: 79.55
# Total Cost per Year: 1561.07
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 977 - EOQ Results:
# Optimal Order Quantity (Q): 160.46
# Number of Orders per Year: 5.95
# Time Between Orders (Months): 2.02
# Cycle Service Level: nan%
# Average Inventory Level: 80.23
# Total Cost per Year: 1817.11
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 978 - EOQ Results:
# Optimal Order Quantity (Q): 144.09
# Number of Orders per Year: 5.26
# Time Between Orders (Months): 2.28
# Cycle Service Level: nan%
# Average Inventory Level: 72.04
# Total Cost per Year: 1606.22
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 979 - EOQ Results:
# Optimal Order Quantity (Q): 165.42
# Number of Orders per Year: 5.09
# Time Between Orders (Months): 2.36
# Cycle Service Level: nan%
# Average Inventory Level: 82.71
# Total Cost per Year: 1559.42
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 980 - EOQ Results:
# Optimal Order Quantity (Q): 176.12
# Number of Orders per Year: 6.11
# Time Between Orders (Months): 1.96
# Cycle Service Level: nan%
# Average Inventory Level: 88.06
# Total Cost per Year: 1868.13
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 981 - EOQ Results:
# Optimal Order Quantity (Q): 189.31
# Number of Orders per Year: 5.70
# Time Between Orders (Months): 2.11
# Cycle Service Level: nan%
# Average Inventory Level: 94.66
# Total Cost per Year: 1747.05
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 982 - EOQ Results:
# Optimal Order Quantity (Q): 190.48
# Number of Orders per Year: 5.47
# Time Between Orders (Months): 2.19
# Cycle Service Level: nan%
# Average Inventory Level: 95.24
# Total Cost per Year: 1680.09
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 983 - EOQ Results:
# Optimal Order Quantity (Q): 170.03
# Number of Orders per Year: 5.31
# Time Between Orders (Months): 2.26
# Cycle Service Level: nan%
# Average Inventory Level: 85.02
# Total Cost per Year: 1627.77
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 984 - EOQ Results:
# Optimal Order Quantity (Q): 165.79
# Number of Orders per Year: 6.00
# Time Between Orders (Months): 2.00
# Cycle Service Level: nan%
# Average Inventory Level: 82.90
# Total Cost per Year: 1834.04
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 985 - EOQ Results:
# Optimal Order Quantity (Q): 165.47
# Number of Orders per Year: 6.04
# Time Between Orders (Months): 1.99
# Cycle Service Level: nan%
# Average Inventory Level: 82.73
# Total Cost per Year: 1845.48
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 986 - EOQ Results:
# Optimal Order Quantity (Q): 158.84
# Number of Orders per Year: 5.57
# Time Between Orders (Months): 2.16
# Cycle Service Level: nan%
# Average Inventory Level: 79.42
# Total Cost per Year: 1701.67
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 987 - EOQ Results:
# Optimal Order Quantity (Q): 179.38
# Number of Orders per Year: 6.41
# Time Between Orders (Months): 1.87
# Cycle Service Level: nan%
# Average Inventory Level: 89.69
# Total Cost per Year: 1959.74
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 988 - EOQ Results:
# Optimal Order Quantity (Q): 176.15
# Number of Orders per Year: 6.17
# Time Between Orders (Months): 1.94
# Cycle Service Level: nan%
# Average Inventory Level: 88.08
# Total Cost per Year: 1887.70
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 989 - EOQ Results:
# Optimal Order Quantity (Q): 177.05
# Number of Orders per Year: 5.52
# Time Between Orders (Months): 2.17
# Cycle Service Level: nan%
# Average Inventory Level: 88.53
# Total Cost per Year: 1692.37
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 990 - EOQ Results:
# Optimal Order Quantity (Q): 169.81
# Number of Orders per Year: 5.90
# Time Between Orders (Months): 2.03
# Cycle Service Level: nan%
# Average Inventory Level: 84.90
# Total Cost per Year: 1805.40
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 991 - EOQ Results:
# Optimal Order Quantity (Q): 168.39
# Number of Orders per Year: 6.06
# Time Between Orders (Months): 1.98
# Cycle Service Level: nan%
# Average Inventory Level: 84.20
# Total Cost per Year: 1852.37
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 992 - EOQ Results:
# Optimal Order Quantity (Q): 149.00
# Number of Orders per Year: 5.34
# Time Between Orders (Months): 2.25
# Cycle Service Level: nan%
# Average Inventory Level: 74.50
# Total Cost per Year: 1632.16
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 993 - EOQ Results:
# Optimal Order Quantity (Q): 161.71
# Number of Orders per Year: 6.03
# Time Between Orders (Months): 1.99
# Cycle Service Level: nan%
# Average Inventory Level: 80.85
# Total Cost per Year: 1841.68
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 994 - EOQ Results:
# Optimal Order Quantity (Q): 161.57
# Number of Orders per Year: 5.77
# Time Between Orders (Months): 2.08
# Cycle Service Level: nan%
# Average Inventory Level: 80.79
# Total Cost per Year: 1762.46
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 995 - EOQ Results:
# Optimal Order Quantity (Q): 161.49
# Number of Orders per Year: 5.57
# Time Between Orders (Months): 2.15
# Cycle Service Level: nan%
# Average Inventory Level: 80.74
# Total Cost per Year: 1703.94
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 996 - EOQ Results:
# Optimal Order Quantity (Q): 162.29
# Number of Orders per Year: 5.99
# Time Between Orders (Months): 2.00
# Cycle Service Level: nan%
# Average Inventory Level: 81.15
# Total Cost per Year: 1829.04
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 997 - EOQ Results:
# Optimal Order Quantity (Q): 188.38
# Number of Orders per Year: 6.26
# Time Between Orders (Months): 1.92
# Cycle Service Level: nan%
# Average Inventory Level: 94.19
# Total Cost per Year: 1916.48
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 998 - EOQ Results:
# Optimal Order Quantity (Q): 187.11
# Number of Orders per Year: 5.69
# Time Between Orders (Months): 2.11
# Cycle Service Level: nan%
# Average Inventory Level: 93.55
# Total Cost per Year: 1743.51
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 999 - EOQ Results:
# Optimal Order Quantity (Q): 169.57
# Number of Orders per Year: 5.56
# Time Between Orders (Months): 2.16
# Cycle Service Level: nan%
# Average Inventory Level: 84.79
# Total Cost per Year: 1702.00
# Lead Time Demand: 0.00
# --------------------------------------------------
#
# Scenario 1000 - EOQ Results:
# Optimal Order Quantity (Q): 185.12
# Number of Orders per Year: 5.71
# Time Between Orders (Months): 2.10
# Cycle Service Level: nan%
# Average Inventory Level: 92.56
# Total Cost per Year: 1750.36
# Lead Time Demand: 0.00
# --------------------------------------------------
